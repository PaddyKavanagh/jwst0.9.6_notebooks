# %% [markdown]
# # # Run level 2A, 2B and 3 steps on MRS data using jwst step classes

# %% [markdown]
# ### by Patrick Kavanagh (DIAS, Ireland) July 5th 2018

# %% [markdown]
# This notebook demonstrates the execution of the level 2A, 2B, and 3 pipeline steps for MRS data in Python using the jwst step classes.
#
# For a description of the step classes see:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/package_index.html
#
# The files used in this notebook is a MIRISim simulation of a point source with power-law (alpha=0) plus emission lines spectrum. The simulated observation is a four-point dither on the source with the channels 1 and 2, and the SHORT disperser.
#
# We will run through the level 2A and 2B pipeline steps on one file only, bringing the remaining files to level 2B using the pipeline classes before running level 3 steps. We will save the output of each step to file so the user can have a look if they want. ### note that this will take up significant hardrive space.
#
# We will pass the output of one step to the next in datamodel form. More information on the datamodels can be found here:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/datamodels/index.html

# %% [markdown]
# #### imports

# %%
import os, glob, shutil
from subprocess import call

import numpy as np
from astropy.io import fits
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt

from jwst import datamodels

# %matplotlib inline
# %matplotlib notebook # if you want interactive plots

# %% [markdown]
# #### Set input file, output directory for step outputs:

# %%
# set input filenames and directory. In this example, the files are located in a folder called 'MRS_demo_data'
input_dir = 'MRS_demo_data'
input_files = glob.glob(os.path.join(input_dir,'*.fits'))

# set the output directory name
output_dir = input_dir + '_tutorial'

# if the output directory exists, delete it
if os.path.exists(output_dir): shutil.rmtree(output_dir)

# create the output directory
os.mkdir(output_dir)

# %% [markdown]
# #### print some information about the input file.
# Note that ground test data and MIRISim data will differ here. We can distinguish between the two using the 'ORIGIN' header keyword. Converted ground test data will always have 'STScI' as the origin.
#
# Also note that there is currently a problem running MIRISim data step-wise through the pipeline. One must remove some of the extensions. This has been taken care of in the following cell. This issue has been reported to STScI and this notebook will be updated when it is resolved.

# %%
# print some info on input file
with fits.open(input_files[0]) as hdulist:
    
    if hdulist[0].header['ORIGIN'] == 'STScI':
        # specific information on instrument/exposure
        identifier = hdulist[0].header['OBS_ID']
        detector = hdulist[0].header['DETECTOR']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print("ID\t\t\t\t Detector\t nInts\t nGrps\t rdPatt\t subAr\t chan.\t band")
        print("--------------------------------------------------------------------------------------------------")
        print("%s\t %s\t %d\t %s\t %s\t %s\t %s\t %s" % (identifier,detector,nInts,nGroups,readPatt,subArr,channel,band))
        print("\n\n")
        
    else:
        # specific information on instrument/exposure
        detector = hdulist[0].header['DETECTOR']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print("ID\t Detector\t nInts\t nGrps\t rdPatt\t chan.\t band")
        print("--------------------------------------------------------------------------------------------------")
        print("MIRISim\t %s\t %d\t %s\t %s\t %s\t %s" % (detector,nInts,nGroups,readPatt,channel,band))
        print("\n\n")
        
    # fits extension table
    hdulist.info()
# Out:
# ID	 Detector	 nInts	 nGrps	 rdPatt	 chan.	 band
# --------------------------------------------------------------------------------------------------
# MIRISim	 MIRIFUSHORT	 2	 50	 FAST	 12	 SHORT
#
#
#
# Filename: MRS_demo_data/det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     110   ()
#   1  SCI           1 ImageHDU        54   (1032, 1024, 50, 2)   float32
#   2  PIXELDQ       1 ImageHDU        11   (1032, 1024)   int32 (rescales to uint32)
#   3  GROUPDQ       1 ImageHDU        11   (1032, 1024, 50, 2)   uint8
#   4  ERR           1 ImageHDU        11   (1032, 1024, 50, 2)   float32
#   5  REFOUT        1 ImageHDU        12   (258, 1024, 50, 2)   float32
#   6  ASDF          1 BinTableHDU     11   5469R x 1C   [B]

# %% [markdown]
# ## DQ_INIT step ===================================================
# This step creates the PIXELDQ, GROUPDQ and ERR extensions in the ramp file
# which are copied from the calibration file. See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/dq_init/index.html

# %% [markdown]
# ### DQ_INIT: load module and show options

# %%
# import the step
from jwst.dq_init import dq_init_step

# print the description and options
print(dq_init_step.DQInitStep.__doc__)
print(dq_init_step.DQInitStep.spec)
# Out:
#     DQInitStep:  Initialize the Data Quality extension from the
#     mask reference file.  Also initialize the error extension
#
#
#
#     pre_hooks          = string_list(default=list())
#     post_hooks         = string_list(default=list())
#     output_file        = output_file(default=None)   # File to save output to.
#     output_dir         = string(default=None)        # Directory path for output files
#     output_ext         = string(default='.fits')     # Default type of output
#     output_use_model   = boolean(default=False)      # When saving use `DataModel.meta.filename`
#     output_use_index   = boolean(default=True)       # Append index.
#     save_results       = boolean(default=False)      # Force save results
#     skip               = boolean(default=False)      # Skip this step
#     suffix             = string(default=None)        # Default suffix for output files
#     search_output_file = boolean(default=True)       # Use outputfile define in parent step
#     input_dir          = string(default=None)        # Input directory

# %% [markdown]
# ### DQ_INIT: run step

# %%
# run the dq_init step
dm = dq_init_step.DQInitStep.call(input_files[0], save_results=True, output_use_model=True, 
                                  output_dir=output_dir)
# Out:
# 2019-01-31 13:59:52,700 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2019-01-31 13:59:52,791 - stpipe.DQInitStep - INFO - Step DQInitStep running with args ('MRS_demo_data/det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits',).
# 2019-01-31 13:59:52,920 - stpipe.DQInitStep - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0022.fits
# 2019-01-31 14:00:00,528 - stpipe.DQInitStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_dqinitstep.fits
# 2019-01-31 14:00:00,529 - stpipe.DQInitStep - INFO - Step DQInitStep done

# %% [markdown]
# ### DQ_INIT:  output check
#
# 1. check the output datamodel to show values in the new extensions, check that some pixels have been assigned new flags from the mask file

# %%
# check the calibration step information
print('Check dq_init step information status:')
print(dm.meta.cal_step.dq_init)

# print unique values in the PIXELDQ extension
print("\nDQ flags values in PIXELDQ:")
print(', '.join(map(str, np.unique(dm.pixeldq))))

# print unique values in the GROUPDQ extension
print("\nDQ flags values in GROUPDQ extension:")
print(', '.join(map(str, np.unique(dm.groupdq))))
# Out:
# Check dq_init step information status:
# COMPLETE
#
# DQ flags values in PIXELDQ:
# 0, 2049, 16385, 16777217, 2147484160
#
# DQ flags values in GROUPDQ extension:
# 0

# %% [markdown]
# ### DQ_INIT:  output plots
#
# 1. plot the science data
#
# 2. plot the PIXEL_DQ extension to show which pixels have been flagged

# %%
# plot--------------------------------------
fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# show last frame of first integration
axs[0].imshow(dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', 
              norm=LogNorm(vmin=1e4,vmax=1.5e4))
axs[0].annotate('SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

# plot the PIXEL_DQ frame
axs[1].imshow(dm.pixeldq, cmap='gray', interpolation='nearest', origin='lower', vmin=0, vmax=1)
axs[1].annotate('PIXELDQ', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## SATURATION step ============================================
# The saturation step flags saturated pixel for each integration by reading the calibration reference
# file that specifies the saturation level for each pixel. The saturation flags are set in the fram of the GROUPDQ extension where the pixel reaches saturation. See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/saturation/index.html

# %% [markdown]
# ### SATURATION: load module and show options

# %%
# import the step
from jwst.saturation import saturation_step

# print the description and options
print(saturation_step.SaturationStep.__doc__)
print(saturation_step.SaturationStep.spec)
# Out:
#     This Step sets saturation flags.
#
#
#     pre_hooks          = string_list(default=list())
#     post_hooks         = string_list(default=list())
#     output_file        = output_file(default=None)   # File to save output to.
#     output_dir         = string(default=None)        # Directory path for output files
#     output_ext         = string(default='.fits')     # Default type of output
#     output_use_model   = boolean(default=False)      # When saving use `DataModel.meta.filename`
#     output_use_index   = boolean(default=True)       # Append index.
#     save_results       = boolean(default=False)      # Force save results
#     skip               = boolean(default=False)      # Skip this step
#     suffix             = string(default=None)        # Default suffix for output files
#     search_output_file = boolean(default=True)       # Use outputfile define in parent step
#     input_dir          = string(default=None)        # Input directory

# %% [markdown]
# ### SATURATION: run step

# %%
# run the saturation step
dm = saturation_step.SaturationStep.call(dm, save_results=True, output_use_model=True, 
                                         output_dir=output_dir)
# Out:
# 2019-01-31 14:00:38,686 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2019-01-31 14:00:38,801 - stpipe.SaturationStep - INFO - Step SaturationStep running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_dqinitstep.fits>,).
# 2019-01-31 14:00:38,838 - stpipe.SaturationStep - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0023.fits
# 2019-01-31 14:00:48,847 - stpipe.SaturationStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_saturationstep.fits
# 2019-01-31 14:00:48,848 - stpipe.SaturationStep - INFO - Step SaturationStep done

# %% [markdown]
# ### SATURATION:  output check
#
# 1. saturated pixels will be flagged in the GROUPDQ extension with the number 2. Check that some pixels in this extension are now flagged as saturated

# %%
# check the calibration step information
print('Check saturation step information status:')
print(dm.meta.cal_step.saturation)

# print unique values in the GROUPDQ extension
print("\nDQ flags values in GROUPDQ extension:")
print(', '.join(map(str, np.unique(dm.groupdq))))
# Out:
# Check saturation step information status:
# COMPLETE
#
# DQ flags values in GROUPDQ extension:
# 0

# %% [markdown]
# ### SATURATION:  output plots
#
# 1. plot the science data
#
# 2. plot the GROUP_DQ extension to show which pixels have been flagged as saturated (will be blank if no saturated pixels)

# %%
# plot--------------------------------------   
fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# show last frame of first integration
axs[0].imshow(dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', 
              norm=LogNorm(vmin=1e4,vmax=1.5e4))
axs[0].annotate('SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

# plot last frame of first integration GROUP_DQ
axs[1].imshow(np.sum(dm.groupdq[0],axis=0), cmap='gray', interpolation='nearest', origin='lower', vmin=0, vmax=1)
axs[1].annotate('GROUPDQ', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## LINEARITY step ===============================================
#
# This step corrects for detector non-linearity. The linearity coefficients are read from the linearity correction reference file.
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/linearity/index.html

# %% [markdown]
# ### LINEARITY: load module and show options

# %%
# import the step
from jwst.linearity import linearity_step

# print the description and options
print(linearity_step.LinearityStep.__doc__)
print(linearity_step.LinearityStep.spec)

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     LinearityStep: This step performs a correction for non-linear
#     detector response, using the "classic" polynomial method.
#
#
#     pre_hooks          = string_list(default=list())
#     post_hooks         = string_list(default=list())
#     output_file        = output_file(default=None)   # File to save output to.
#     output_dir         = string(default=None)        # Directory path for output files
#     output_ext         = string(default='.fits')     # Default type of output
#     output_use_model   = boolean(default=False)      # When saving use `DataModel.meta.filename`
#     output_use_index   = boolean(default=True)       # Append index.
#     save_results       = boolean(default=False)      # Force save results
#     skip               = boolean(default=False)      # Skip this step
#     suffix             = string(default=None)        # Default suffix for output files
#     search_output_file = boolean(default=True)       # Use outputfile define in parent step
#     input_dir          = string(default=None)        # Input directory

# %% [markdown]
# ### LINEARITY: run step

# %%
# run the linearity step
dm = linearity_step.LinearityStep.call(dm, save_results=True, output_use_model=True, 
                                       output_dir=output_dir)
# Out:
# 2019-01-31 14:01:29,805 - stpipe.LinearityStep - INFO - LinearityStep instance created.
# 2019-01-31 14:01:29,892 - stpipe.LinearityStep - INFO - Step LinearityStep running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_saturationstep.fits>,).
# 2019-01-31 14:01:29,927 - stpipe.LinearityStep - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits
# 2019-01-31 14:01:39,932 - stpipe.LinearityStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_linearitystep.fits
# 2019-01-31 14:01:39,933 - stpipe.LinearityStep - INFO - Step LinearityStep done

# %% [markdown]
# ### LINEARITY:  plot output science image to select pixel for inspection

# %%
# plot--------------------------------------
fig, axs = plt.subplots(1, 1, figsize=(8, 8))

# show last frame of first integration
axs.imshow(dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', 
           norm=LogNorm(vmin=1e4,vmax=1.5e4))
axs.annotate('SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### LINEARITY:  input/output ramp comparison
#
# 1. plot the input and output ramps
#
# 2. show the difference between these

# %%
# using image in previous cell, select pixel to check
pixel = [371,600]

# define group numbers for integration ramps
group = range(1,in_dm.data[0,:,pixel[0],pixel[1]].shape[0]+1,1)

# plot--------------------------------------
fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# plot input and output ramps of the first integration
axs[0].plot(group, in_dm.data[0,:,pixel[1],pixel[0]], c='r', marker='^', markersize=6, 
            linestyle='-', linewidth=2, label='input ramp')
axs[0].plot(group, dm.data[0,:,pixel[1],pixel[0]], c='b', marker='o', 
            linestyle='-', linewidth=2, label='linearity calibrated ramp')
axs[0].set_title('linearity correction',fontsize=15)
axs[0].set_ylabel('DN',fontsize=15)
axs[0].set_xlim(-1,max(group)+1)
axs[0].legend(prop={'size':12}, loc=0)

# plot difference
axs[1].plot(group, in_dm.data[0,:,pixel[1],pixel[0]] - dm.data[0,:,pixel[1],pixel[0]], 
            c='g', marker='s', markersize=6, linestyle='-', linewidth=2, label='difference')
axs[1].set_ylabel('DN',fontsize=15)
axs[1].set_xlabel('group',fontsize=15)
axs[1].legend(prop={'size':12}, loc=0)

plt.tight_layout(h_pad=0)
plt.show()

# %% [markdown]
# ## RSCD step ======================================================
# This step corrects for the slow adjustment of the reset FET to the asymtotic level after reset. See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/rscd/index.html

# %% [markdown]
# ### RSCD: load module and show options

# %%
# import the step
from jwst.rscd import rscd_step

# print the description and options
print(rscd_step.RSCD_Step.__doc__)
print(rscd_step.RSCD_Step.spec)

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     RSCD_Step: Performs an RSCD correction to MIRI data by adding a function
#     of time, frame by frame, to a copy of the input science data model.
#
#
#     pre_hooks          = string_list(default=list())
#     post_hooks         = string_list(default=list())
#     output_file        = output_file(default=None)   # File to save output to.
#     output_dir         = string(default=None)        # Directory path for output files
#     output_ext         = string(default='.fits')     # Default type of output
#     output_use_model   = boolean(default=False)      # When saving use `DataModel.meta.filename`
#     output_use_index   = boolean(default=True)       # Append index.
#     save_results       = boolean(default=False)      # Force save results
#     skip               = boolean(default=False)      # Skip this step
#     suffix             = string(default=None)        # Default suffix for output files
#     search_output_file = boolean(default=True)       # Use outputfile define in parent step
#     input_dir          = string(default=None)        # Input directory

# %% [markdown]
# #### RSCD: run step

# %%
# run the rscd step
dm = rscd_step.RSCD_Step.call(dm, save_results=True, output_use_model=True, 
                              output_dir=output_dir)
# Out:
# 2019-01-31 14:02:31,033 - stpipe.RSCD_Step - INFO - RSCD_Step instance created.
# 2019-01-31 14:02:31,107 - stpipe.RSCD_Step - INFO - Step RSCD_Step running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_linearitystep.fits>,).
# 2019-01-31 14:02:31,142 - stpipe.RSCD_Step - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0007.fits
# 2019-01-31 14:03:47,362 - stpipe.RSCD_Step - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_rscd_step.fits
# 2019-01-31 14:03:47,364 - stpipe.RSCD_Step - INFO - Step RSCD_Step done

# %% [markdown]
# ### RSCD:  plot output science image to select pixel for inspection

# %%
# plot--------------------------------------
fig, axs = plt.subplots(1, 1, figsize=(8, 8))

# show last frame of first integration
axs.imshow(dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', 
           norm=LogNorm(vmin=1e4,vmax=1.5e4))
axs.annotate('SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### RSCD:  input/output ramp comparison
#
# 1. plot the input and output ramps. Note that the RSCD step only corrects following a reset show will note perform a correction if there is only one integration in the exposure.
#
# 2. show the difference between the input and output ramps

# %%
# using image in previous cell, select pixel to check, 
# comment out if you want to use pixel defined earlier
#pixel = [560,237]

   
# first check that there is more than one integration
if in_dm.data.shape[0] > 1:

    # plot--------------------------------------
    fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

    # plot input and output ramps of the second integration
    axs[0].plot(group, in_dm.data[-1,:,pixel[1],pixel[0]], c='r', marker='^', markersize=6, 
                linestyle='-', linewidth=2, label='input ramp')
    axs[0].plot(group, dm.data[-1,:,pixel[1],pixel[0]], c='b', marker='o', 
                linestyle='-', linewidth=2, label='RSCD calibrated ramp')
    axs[0].set_title('RSCD correction',fontsize=15)
    axs[0].set_ylabel('DN',fontsize=15)
    axs[0].set_xlim(-1,max(group)+1)
    axs[0].legend(prop={'size':12}, loc=0)

    # plot ratio between the two
    axs[1].plot(group, in_dm.data[-1,:,pixel[1],pixel[0]] / dm.data[-1,:,pixel[1],pixel[0]], 
                c='g', marker='s', markersize=6, linestyle='-', linewidth=2, label='ratio')
    axs[1].set_ylabel('DN',fontsize=15)
    axs[1].set_xlabel('group',fontsize=15)
    axs[1].legend(prop={'size':12}, loc=0)

    plt.tight_layout(h_pad=0)
    plt.show()

else: print("RSCD step only operates on exposures with more than one integration.")

# %% [markdown]
# ## FIRSTFRAME step ==========================================
# This step flags the first frame of an integration. The fits frame is not considered later in ramp-fitting See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/firstframe/index.html

# %% [markdown]
# ### FIRSTFRAME: load module and show options

# %%
# import the step
from jwst.firstframe import firstframe_step

# print the description and options
print(firstframe_step.FirstFrameStep.__doc__)
print(firstframe_step.FirstFrameStep.spec)

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     FirstFrameStep: This is a MIRI specific task.  If the number of groups
#     is greater than 3, the DO_NOT_USE group data quality flag is added to
#     first group.
#
#
#     pre_hooks          = string_list(default=list())
#     post_hooks         = string_list(default=list())
#     output_file        = output_file(default=None)   # File to save output to.
#     output_dir         = string(default=None)        # Directory path for output files
#     output_ext         = string(default='.fits')     # Default type of output
#     output_use_model   = boolean(default=False)      # When saving use `DataModel.meta.filename`
#     output_use_index   = boolean(default=True)       # Append index.
#     save_results       = boolean(default=False)      # Force save results
#     skip               = boolean(default=False)      # Skip this step
#     suffix             = string(default=None)        # Default suffix for output files
#     search_output_file = boolean(default=True)       # Use outputfile define in parent step
#     input_dir          = string(default=None)        # Input directory

# %% [markdown]
# ### FIRSTFRAME: run step

# %%
# run the firstframe step
dm = firstframe_step.FirstFrameStep.call(dm, save_results=True, output_use_model=True, 
                                         output_dir=output_dir)
# Out:
# 2019-01-31 14:07:23,159 - stpipe.FirstFrameStep - INFO - FirstFrameStep instance created.
# 2019-01-31 14:07:23,234 - stpipe.FirstFrameStep - INFO - Step FirstFrameStep running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_rscd_step.fits>,).
# 2019-01-31 14:07:31,164 - stpipe.FirstFrameStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_firstframestep.fits
# 2019-01-31 14:07:31,166 - stpipe.FirstFrameStep - INFO - Step FirstFrameStep done

# %% [markdown]
# ### FIRSTFRAME:  input/output ramp comparison
#
# This correction flags the first frame of an integration so we can check that the last frame has indeed been flagged in the groupDQ extension.
#
# 1. plot the first frame of the first integration of the GROUPDQ extension, show values of flags (should be solid colour)
#
# 2. plot the input and output GROUPDQ to show that last frame has been flagged

# %%
# define an input and output integration ramp for a given pixel
# using image in previous cell, select pixel to check, 
# comment out if you want to use pixel defined earlier
#pixel = [560,237]

# plot--------------------------------------
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# plot the first frame of the first integration of the GROUPDQ extension
axs[0].imshow(dm.groupdq[-1][-1], cmap='jet', interpolation='nearest', origin='lower')
axs[0].annotate('first frame of GROUPDQ', xy=(0.0, 1.02), xycoords='axes fraction', 
                fontsize=12, fontweight='bold', color='k')

# determine the values in this GROUPDQ frame
flag_values = np.unique(dm.groupdq[0][0])
axs[0].annotate('Flag values in first frame: %s' % flag_values, xy=(0.05, 0.92), 
                xycoords='axes fraction', fontsize=12, fontweight='bold', color='w')

# input and output ramps (setting a slight offset for the output ramp)
axs[1].plot(group, in_dm.groupdq[-1,:,pixel[1],pixel[0]], c='r', marker='^', markersize=6, 
            linestyle='-', linewidth=2, label='input flags')
axs[1].plot(group, dm.groupdq[-1,:,pixel[1],pixel[0]]+0.1, c='b', marker='o', linestyle='-', 
            linewidth=2, label='firstframe flagged (+0.1)')
axs[1].set_title('firstframe step',fontsize=15)
axs[1].set_ylabel('flag values',fontsize=15)
axs[1].set_xlim(-1,max(group)+1)
axs[1].set_ylim(-0.5,1.5)
axs[1].legend(prop={'size':12}, loc=2)

plt.tight_layout(h_pad=0)
plt.show()

# %% [markdown]
# ## LASTFRAME step ==========================================
# This step flags the last frame of an integration. The last frame is not considered later in ramp-fitting See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/lastframe/index.html

# %% [markdown]
# ### LASTFRAME: load module and show options

# %%
# import the step
from jwst.lastframe import lastframe_step

# print the description and options
print(lastframe_step.LastFrameStep.__doc__)
print(lastframe_step.LastFrameStep.spec)

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     LastFrameStep: This is a MIRI specific task.  If the number of groups
#     is greater than 2, the GROUP data quality flags for the final group will
#     be set to DO_NOT_USE.
#
#
#     pre_hooks          = string_list(default=list())
#     post_hooks         = string_list(default=list())
#     output_file        = output_file(default=None)   # File to save output to.
#     output_dir         = string(default=None)        # Directory path for output files
#     output_ext         = string(default='.fits')     # Default type of output
#     output_use_model   = boolean(default=False)      # When saving use `DataModel.meta.filename`
#     output_use_index   = boolean(default=True)       # Append index.
#     save_results       = boolean(default=False)      # Force save results
#     skip               = boolean(default=False)      # Skip this step
#     suffix             = string(default=None)        # Default suffix for output files
#     search_output_file = boolean(default=True)       # Use outputfile define in parent step
#     input_dir          = string(default=None)        # Input directory

# %% [markdown]
# ### LASTFRAME: run step

# %%
# run the lastframe step
dm = lastframe_step.LastFrameStep.call(dm, save_results=True, output_use_model=True, 
                                       output_dir=output_dir)
# Out:
# 2019-01-31 14:07:54,897 - stpipe.LastFrameStep - INFO - LastFrameStep instance created.
# 2019-01-31 14:07:54,959 - stpipe.LastFrameStep - INFO - Step LastFrameStep running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_firstframestep.fits>,).
# 2019-01-31 14:08:27,939 - stpipe.LastFrameStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_lastframestep.fits
# 2019-01-31 14:08:27,940 - stpipe.LastFrameStep - INFO - Step LastFrameStep done

# %% [markdown]
# ### LASTFRAME:  input/output ramp comparison
#
# This correction flags the last frame of an integration so we can check that the last frame has indeed been flagged in the groupDQ extension.
#
# 1. plot the last frame of the first integration of the GROUPDQ extension, show values of flags (should be solid colour)
#
# 2. plot the input and output GROUPDQ to show that last frame has been flagged

# %%
# define an input and output integration ramp for a given pixel
# using image in previous cell, select pixel to check, 
# comment out if you want to use pixel defined earlier
#pixel = [560,237]

# plot--------------------------------------
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# plot the last frame of the first integration of the GROUPDQ extension
axs[0].imshow(dm.groupdq[-1][-1], cmap='jet', interpolation='nearest', origin='lower')
axs[0].annotate('last frame of GROUPDQ', xy=(0.0, 1.02), xycoords='axes fraction', 
                fontsize=12, fontweight='bold', color='k')

# determine the values in this GROUPDQ frame
flag_values = np.unique(dm.groupdq[-1][-1])
axs[0].annotate('Flag values in last frame: %s' % flag_values, xy=(0.05, 0.92), xycoords='axes fraction', 
                fontsize=12, fontweight='bold', color='w')

# input and output ramps (setting a slight offset for the output ramp)
axs[1].plot(group, in_dm.groupdq[-1,:,pixel[1],pixel[0]], c='r', marker='^', markersize=6, 
            linestyle='-', linewidth=2, label='input flags')
axs[1].plot(group, dm.groupdq[-1,:,pixel[1],pixel[0]]+0.1, c='b', marker='o', 
            linestyle='-', linewidth=2, label='lastframe flagged (+0.1)')
axs[1].set_title('lastframe correction',fontsize=15)
axs[1].set_ylabel('flag values',fontsize=15)
axs[1].set_xlim(-1,max(group)+1)
axs[1].set_ylim(-0.5,1.5)
axs[1].legend(prop={'size':12}, loc=2)

plt.tight_layout(h_pad=0)
plt.show()

# %% [markdown]
# ## DARK_CURRENT step ==========================================
#
# This step removes the dark current by subtracting a dark current reference file.
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/dark_current/index.html
#
# Note that there is only 200 frames in the dark reference file integration. If your data has more than 200 frames per integration, the step will be skipped.

# %% [markdown]
# ### DARK_CURRENT: load module and show options

# %%
# import the step
from jwst.dark_current import dark_current_step

# print the description and options
print(dark_current_step.DarkCurrentStep.__doc__)
print(dark_current_step.DarkCurrentStep.spec)

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     DarkCurrentStep: Performs dark current correction by subtracting
#     dark current reference data from the input science data model.
#
#
#         dark_output = output_file(default = None) # Dark model or averaged dark subtracted

# %% [markdown]
# ### DARK_CURRENT: run step

# %%
# run the dark_current step
dm = dark_current_step.DarkCurrentStep.call(dm, save_results=True, output_use_model=True, 
                                            output_dir=output_dir)
# Out:
# 2019-01-31 14:08:55,868 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2019-01-31 14:08:55,929 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_lastframestep.fits>,).
# 2019-01-31 14:08:55,965 - stpipe.DarkCurrentStep - INFO - Using DARK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0056.fits
# 2019-01-31 14:08:56,247 - stpipe.DarkCurrentStep - INFO - Science data nints=2, ngroups=50, nframes=1, groupgap=0
# 2019-01-31 14:08:56,248 - stpipe.DarkCurrentStep - INFO - Dark data nints=2, ngroups=200, nframes=1, groupgap=0
# 2019-01-31 14:09:25,055 - stpipe.DarkCurrentStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_darkcurrentstep.fits
# 2019-01-31 14:09:25,056 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep done

# %% [markdown]
# ### DARK_CURRENT:  plot output science image to select pixel for inspection

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 8))

# show last frame of first integration
axs.imshow(dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', 
           norm=LogNorm(vmin=1e4,vmax=1.5e4))
axs.annotate('SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### DARK_CURRENT:  input/output ramp comparison
#
# 1. plot the input and output ramps
#
# 2. show the difference between these

# %%
# using image in previous cell, select pixel to check, 
# comment out if you want to use pixel defined earlier
#pixel = [560,237]

# plot--------------------------------------
fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# plot input and output ramps of the second integration
axs[0].plot(group, in_dm.data[0,:,pixel[1],pixel[0]], c='r', marker='^', markersize=6, 
            linestyle='-', linewidth=2, label='input ramp')
axs[0].plot(group, dm.data[0,:,pixel[1],pixel[0]], c='b', marker='o', 
            linestyle='-', linewidth=2, label='dark calibrated ramp')
axs[0].set_title('dark current correction',fontsize=15)
axs[0].set_ylabel('DN',fontsize=15)
axs[0].set_xlim(-1,max(group)+1)
axs[0].legend(prop={'size':12}, loc=0)

# plot difference between the two
axs[1].plot(group, in_dm.data[0,:,pixel[1],pixel[0]] - dm.data[0,:,pixel[1],pixel[0]], 
            c='g', marker='s', markersize=6, linestyle='-', linewidth=2, label='difference')
axs[1].set_ylabel('DN',fontsize=15)
axs[1].set_xlabel('group',fontsize=15)
axs[1].legend(prop={'size':12}, loc=0)

plt.tight_layout(h_pad=0)
plt.show()

# %% [markdown]
# ## REFPIX step =============================================
# This step corrects for electronic drift effects in the data by applying the reference pixel correction. See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/refpix/index.html
#
# Note that this should be skipped for MIRISim data for the time being.

# %% [markdown]
# ### REFPIX: load module and show options

# %%
# import the step
from jwst.refpix import refpix_step

# print the description and options
print(refpix_step.RefPixStep.__doc__)
print(refpix_step.RefPixStep.spec)

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     RefPixStep: Use reference pixels to correct bias drifts
#
#
#
#         odd_even_columns = boolean(default=True)
#         use_side_ref_pixels = boolean(default=True)
#         side_smoothing_length = integer(default=11)
#         side_gain = float(default=1.0)
#         odd_even_rows = boolean(default=True)

# %% [markdown]
# ### REFPIX: run step

# %%
# run the refpix step
dm = refpix_step.RefPixStep.call(dm, save_results=True, output_use_model=True, 
                                 output_dir=output_dir, skip=True)
# Out:
# 2019-01-31 14:11:07,292 - stpipe.RefPixStep - INFO - RefPixStep instance created.
# 2019-01-31 14:11:07,384 - stpipe.RefPixStep - INFO - Step RefPixStep running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_darkcurrentstep.fits>,).
# 2019-01-31 14:11:07,385 - stpipe.RefPixStep - INFO - Step skipped.
# 2019-01-31 14:11:07,386 - stpipe.RefPixStep - INFO - Step RefPixStep done

# %% [markdown]
# ### REFPIX:  plot output science image to select pixel for inspection

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 8))

# show last frame of first integration
axs.imshow(dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=9e3,vmax=1.5e4))
axs.annotate('SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### REFPIX:  input/output ramp comparison
#
# 1. plot the input and output ramps
#
# 2. show the difference between these

# %%
# using image in previous cell, select pixel to check, 
# comment out if you want to use pixel defined earlier
#pixel = [560,237]


# plot--------------------------------------
fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# plot input and output ramps of the second integration
axs[0].plot(group, in_dm.data[0,:,pixel[1],pixel[0]], c='r', marker='^', markersize=6, linestyle='-', linewidth=2, label='input ramp')
axs[0].plot(group, dm.data[0,:,pixel[1],pixel[0]], c='b', marker='o', linestyle='-', linewidth=2, label='refpix calibrated ramp')
axs[0].set_title('refpix correction',fontsize=15)
axs[0].set_ylabel('DN',fontsize=15)
axs[0].set_xlim(-1,max(group)+1)
axs[0].legend(prop={'size':12}, loc=0)

# plot difference between the two
axs[1].plot(group, in_dm.data[0,:,pixel[1],pixel[0]] - dm.data[0,:,pixel[1],pixel[0]], c='g', marker='s', markersize=6, linestyle='-', linewidth=2, label='difference')
axs[1].set_ylabel('DN',fontsize=15)
axs[1].set_xlabel('group',fontsize=15)
axs[1].legend(prop={'size':12}, loc=0)

plt.tight_layout(h_pad=0)
plt.show()

# %% [markdown]
# ## JUMP detection =================================================
#
# This step detects jumps in the ramp by looking for outliers from the ramp. It updates the GROUPDQ array to indicate where a jump was found.
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/jump/index.html

# %% [markdown]
# ### JUMP: load module and show options

# %%
# import the step
from jwst.jump import jump_step

# print the description and options
print(jump_step.JumpStep.__doc__)
print(jump_step.JumpStep.spec)

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     JumpStep: Performs CR/jump detection on each ramp integration within an
#     exposure. The 2-point difference method is applied.
#
#
#         rejection_threshold = float(default=4.0,min=0) # CR rejection threshold

# %% [markdown]
# ### JUMP: run step

# %%
# run the jump step
dm = jump_step.JumpStep.call(dm, save_results=True, output_use_model=True, 
                                 output_dir=output_dir)
# Out:
# 2019-01-31 16:15:25,164 - stpipe.JumpStep - INFO - JumpStep instance created.
# 2019-01-31 16:15:25,304 - stpipe.JumpStep - INFO - Step JumpStep running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_darkcurrentstep.fits>,).
# 2019-01-31 16:15:25,358 - stpipe.JumpStep - INFO - CR rejection threshold = 4 sigma
# 2019-01-31 16:15:25,365 - stpipe.JumpStep - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2019-01-31 16:15:25,423 - stpipe.JumpStep - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2019-01-31 16:15:27,036 - stpipe.JumpStep - INFO - Executing two-point difference method
# 2019-01-31 16:15:27,659 - stpipe.JumpStep - INFO -  working on integration 1
# 2019-01-31 16:15:31,085 - stpipe.JumpStep - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/jump/twopoint_difference.py:83: RuntimeWarning: invalid value encountered in sqrt
#   poisson_noise = np.sqrt(np.abs(med_diffs))
#
# 2019-01-31 16:15:46,877 - stpipe.JumpStep - INFO -  working on integration 2
# 2019-01-31 16:16:11,788 - stpipe.JumpStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_jumpstep.fits
# 2019-01-31 16:16:11,789 - stpipe.JumpStep - INFO - Step JumpStep done

# %% [markdown]
# ### JUMP:  plot output science image to select pixel for inspection

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 8))

# show last frame of first integration
axs.imshow(dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', 
           norm=LogNorm(vmin=1e4,vmax=1.5e4))
axs.annotate('SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### JUMP:  input/output ramp comparison
#
# 1. plot the output ramp
#
# 2. show the input and output GROUPDQ vectors and mark where jumps were detected (a flag of >=4 in GROUPDQ). It's possible that no jumps are detected.

# %%
# using image in previous cell, select pixel to check, 
# comment out if you want to use pixel defined earlier
#pixel = [560,237]

# plot--------------------------------------
fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# first integration for input/output ramps
axs[0].plot(group, dm.data[0,:,pixel[1],pixel[0]], c='b', marker='o', linestyle='-', linewidth=2, label='ramp')
axs[0].set_title('jump correction',fontsize=15)
axs[0].set_ylabel('DN',fontsize=15)
axs[0].set_xlim(-1,max(group)+1)
axs[0].set_ylim(min(dm.data[0,:,pixel[1],pixel[0]])-200,max(dm.data[0,:,pixel[1],pixel[0]])+200)
axs[0].legend(prop={'size':12}, loc=2)

# input and output flag values (setting a slight offset for the output flags)
axs[1].plot(group, in_dm.groupdq[0,:,pixel[1],pixel[0]], c='r', marker='^', markersize=6, 
            linestyle='-', linewidth=2, label='input flags')
axs[1].plot(group, dm.groupdq[0,:,pixel[1],pixel[0]]+0.1, c='b', marker='o', 
            linestyle='-', linewidth=2, label='jump flagged (+0.1)')
axs[1].plot([-10,100],[4,4], linestyle='--', linewidth=3, c='g', label='jump threshold')
axs[1].set_ylabel('flag values',fontsize=15)
axs[1].set_ylabel('group dq',fontsize=15)
axs[1].set_xlim(-1,max(group)+1)
axs[1].set_ylim(-0.5,6.5)
axs[1].legend(prop={'size':12}, loc=2)

# draw lines to show the groups which have been flagged as jumps
for n, val in enumerate(group):
    if (dm.groupdq[0,n,pixel[1],pixel[0]] >= 4): 
        axs[0].plot([n+1,n+1],[min(dm.data[0,:,pixel[1],pixel[0]])-200,max(dm.data[0,:,pixel[1],pixel[0]])+200], 
                    linestyle='--', linewidth=0.3, c='k')
        axs[1].plot([n+1,n+1],[-1,6], linestyle='--', linewidth=0.3, c='k')

plt.tight_layout(h_pad=0)
plt.show()

# %% [markdown]
# ## RAMP_FITTING step =========================================
#
# This step caculates the mean count rate for each pixel by performing a linear fit to the ramps. See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/ramp_fitting/index.html
#
# There are two outputs are here:
#
# 1) the slope image  (_rate.fits)
#
# 2) if more than one integration, slope image per integration  (_rateints.fits)
#
# Typically, _rateints.fits is only used for time series observations.

# %% [markdown]
# ### RAMP_FITTING: load module and show options

# %%
# import the step
from jwst.ramp_fitting import ramp_fit_step

# print the description and options
print(ramp_fit_step.RampFitStep.__doc__)
print(ramp_fit_step.RampFitStep.spec)
# Out:
#     This step fits a straight line to the value of counts vs. time to
#     determine the mean count rate for each pixel.
#
#
#         int_name = string(default='')
#         save_opt = boolean(default=False) # Save optional output
#         opt_name = string(default='')

# %% [markdown]
# ### RAMP_FITTING: run step

# %%
# run the ramp_fitting step
dm = ramp_fit_step.RampFitStep.call(dm, save_results=True, output_use_model=True, 
                                    output_dir=output_dir)

# copy datamodel for comparison later
level2A_dm = dm[0].copy()
# Out:
# 2019-01-31 16:16:40,807 - stpipe.RampFitStep - INFO - RampFitStep instance created.
# 2019-01-31 16:16:40,905 - stpipe.RampFitStep - INFO - Step RampFitStep running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_jumpstep.fits>,).
# 2019-01-31 16:16:40,973 - stpipe.RampFitStep - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2019-01-31 16:16:40,999 - stpipe.RampFitStep - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2019-01-31 16:16:41,022 - stpipe.RampFitStep - INFO - Using algorithm = ols
# 2019-01-31 16:16:41,024 - stpipe.RampFitStep - INFO - Using weighting = optimal
# 2019-01-31 16:16:41,029 - stpipe.RampFitStep - INFO - MIRI dataset has all final groups flagged as DO_NOT_USE.
# 2019-01-31 16:16:41,030 - stpipe.RampFitStep - INFO - Effective integration time per group: 2.77504
# 2019-01-31 16:21:50,012 - stpipe.RampFitStep - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:391: RuntimeWarning: divide by zero encountered in true_divide
#   inv_var_p4[num_int, :, :, :] = 1./var_p4[num_int, :, :, :]
#
# 2019-01-31 16:21:50,359 - stpipe.RampFitStep - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:395: RuntimeWarning: divide by zero encountered in true_divide
#   var_p3[num_int, :, :] = 1./ s_inv_var_p3[num_int, :, :]
#
# 2019-01-31 16:21:52,214 - stpipe.RampFitStep - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:457: RuntimeWarning: divide by zero encountered in true_divide
#   var_both3[num_int, :, :] = 1./s_inv_var_both3[num_int, :, :]
#
# 2019-01-31 16:21:58,729 - stpipe.RampFitStep - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:487: RuntimeWarning: divide by zero encountered in true_divide
#   slope_dataset2 = s_slope_by_var2/s_inv_var_both2
#
# 2019-01-31 16:21:59,182 - stpipe.RampFitStep - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:494: RuntimeWarning: invalid value encountered in true_divide
#   slope_int = the_num/the_den
#
# 2019-01-31 16:21:59,204 - stpipe.RampFitStep - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:505: RuntimeWarning: divide by zero encountered in true_divide
#   var_p2 = 1/(s_inv_var_p3.sum(axis=0))
#
# 2019-01-31 16:23:09,272 - stpipe.RampFitStep - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:666: RuntimeWarning: invalid value encountered in sqrt
#   cubemod.err = np.sqrt(var_both3)
#
# 2019-01-31 16:23:09,294 - stpipe.RampFitStep - INFO - Number of groups per integration: 50
# 2019-01-31 16:23:09,294 - stpipe.RampFitStep - INFO - Number of integrations: 2
# 2019-01-31 16:23:10,357 - stpipe.RampFitStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_rampfitstep.fits
# 2019-01-31 16:23:10,618 - stpipe.RampFitStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_rampfitstep.fits
# 2019-01-31 16:23:10,619 - stpipe.RampFitStep - INFO - Step RampFitStep done

# %% [markdown]
# ### RAMP_FITTING:  level 1B and level 2A image comparison
#
# Visually compare the input ramp and the output slope image

# %%
# open the level 1B input as a jwst data model
with datamodels.open(input_files[0]) as in_dm:

    # plot--------------------------------------
    # show the input ramp image and the calibrated
    # slope image.
    fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

    # sum the groups in the first integration of the input ramp image and plot
    axs[0].imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', 
                  norm=LogNorm(vmin=1e4,vmax=1.5e4))
    axs[0].annotate('Input ramp image (level 1B)', xy=(0.0, 1.02), xycoords='axes fraction',
                    fontsize=12, fontweight='bold', color='k')
    axs[0].set_facecolor('black')
    axs[1].imshow(dm[0].data, cmap='jet', interpolation='nearest', origin='lower', vmin=-1, vmax=10)
    axs[1].annotate('Slope image (level 2A)', xy=(0.0, 1.02), xycoords='axes fraction', 
                    fontsize=12, fontweight='bold', color='k')
    axs[1].set_facecolor('black')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ASSIGN_WCS step =================================================
# This step creates a WCS object and associates it with the science file, mapping detector to world coordinates. See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/assign_wcs/index.html

# %%
# import the step
from jwst.assign_wcs import assign_wcs_step

# print the description and options
print(assign_wcs_step.AssignWcsStep.__doc__)
print(assign_wcs_step.AssignWcsStep.spec)
# Out:
#     AssignWcsStep: Create a gWCS object and store it in ``Model.meta``.
#
#     Reference file types:
#
#     camera             Camera model (NIRSPEC)
#     collimator         Collimator Model (NIRSPEC)
#     disperser          Disperser model (NIRSPEC)
#     distortion         Spatial distortion model (FGS, MIRI, NIRCAM, NIRISS)
#     filteroffset       Filter offsets (MIRI Imager)
#     fore               Transform through the FORE optics (NIRSPEC)
#     fpa                Transform in the FPA plane (NIRSPEC)
#     ifufore            Transforms from the MSA plane to the plane of the IFU slicer (NIRSPEC)
#     ifupost            Transforms from the slicer plane to the MSA plane (NIRSPEC)
#     ifuslicer          Metrology of the IFU slicer (NIRSPEC)
#     msa                Metrology of the MSA plane (NIRSPEC)
#     ote                Transform through the Optical Telescope Element (NIRSPEC)
#     specwcs            Wavelength calibration models (MIRI, NIRCAM, NIRISS)
#     regions            Stores location of the regions on the detector (MIRI)
#     wavelengthrange    Typical wavelength ranges (MIRI, NIRCAM, NIRISS, NIRSPEC)
#
#     Parameters
#     ----------
#     input : `~jwst.datamodels.ImageModel`, `~jwst.datamodels.IFUImageModel`, `~jwst.datamodels.CubeModel`
#         Input exposure.

# %% [markdown]
# ### ASSIGN_WCS: run step

# %%
# run the assign_wcs step
dm = assign_wcs_step.AssignWcsStep.call(dm[0], save_results=True, output_use_model=True, 
                                        output_dir=output_dir)
# Out:
# 2019-01-31 16:30:57,015 - stpipe.AssignWcsStep - INFO - AssignWcsStep instance created.
# 2019-01-31 16:30:57,382 - stpipe.AssignWcsStep - INFO - Step AssignWcsStep running with args (<IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_rampfitstep.fits>,).
# 2019-01-31 16:31:09,905 - stpipe.AssignWcsStep - INFO - assign_wcs did not update S_REGION for type MIR_MRS
# 2019-01-31 16:31:09,906 - stpipe.AssignWcsStep - INFO - COMPLETED assign_wcs
# 2019-01-31 16:31:11,580 - stpipe.AssignWcsStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_assignwcsstep.fits
# 2019-01-31 16:31:11,581 - stpipe.AssignWcsStep - INFO - Step AssignWcsStep done

# %% [markdown]
# ### ASSIGN_WCS:  plot output science image to select pixel for inspection

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 8))

# show last frame of first integration
axs.imshow(dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=-1, vmax=10)
axs.annotate('SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### ASSIGN_WCS: perform some transforms
#
# 1. Display the available coordinate frames
#
# 2. perform some transfer from pixel to WCS

# %%
# using image in previous cell, select pixel to check, 
# comment out if you want to use pixel defined earlier
#pixel = [560,237]

# print available coordinate frames
print("Available coordinate frames:" )
print(", ".join(dm.meta.wcs.available_frames))
print("")

# perform transforms on pixel
ra, dec, wav = dm.meta.wcs(pixel[0],pixel[1])

print("Pixel: %d, %d" % (pixel[0],pixel[1]))
print("assign_wcs RA, DEC (deg): %0.7f %0.7f" % (ra,dec))
print("assing_wcs Wavelength (micron): %0.3f" % wav)
# Out:
# Available coordinate frames:
# detector, alpha_beta, v2v3, world
#
# Pixel: 371, 600
# assign_wcs RA, DEC (deg): -0.0000347 -0.0000196
# assing_wcs Wavelength (micron): 5.418

# %% [markdown]
# ## FLAT_FIELD step =============================================
# The flat_field step divides the image by a flat-field reference image and updates the DQ array to indicate where no flat-field is available for a pixel. See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/flatfield/index.html

# %% [markdown]
# ### FLAT_FIELD: load module and show options

# %%
# import the step
from jwst.flatfield import flat_field_step

# print the description and options
print(flat_field_step.FlatFieldStep.__doc__)
print(flat_field_step.FlatFieldStep.spec)

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     FlatFieldStep: Flat-field a science image using a flatfield reference image.
#
#
#         # Suffix for optional output file for interpolated flat fields.
#         # Note that this is only used for NIRSpec spectrographic data.
#         flat_suffix = string(default=None)

# %% [markdown]
# ### FLAT_FIELD: run step

# %%
# run the flat_field step
dm = flat_field_step.FlatFieldStep.call(dm, save_results=True, output_use_model=True, 
                                        output_dir=output_dir)
# Out:
# 2019-01-31 16:31:13,593 - stpipe.FlatFieldStep - INFO - FlatFieldStep instance created.
# 2019-01-31 16:31:13,752 - stpipe.FlatFieldStep - INFO - Step FlatFieldStep running with args (<IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_assignwcsstep.fits>,).
# 2019-01-31 16:31:13,858 - stpipe.FlatFieldStep - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-01-31 16:31:16,338 - stpipe.FlatFieldStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_flatfieldstep.fits
# 2019-01-31 16:31:16,339 - stpipe.FlatFieldStep - INFO - Step FlatFieldStep done

# %% [markdown]
# ### FLAT_FIELD: input/output image checks
#
# 1. Display the input and output images
# 2. Show the ratio of the two

# %%
# plot--------------------------------------
# show the input, output and ratio image, 
# which will correspond to the flat field.
fig, axs = plt.subplots(1, 3, figsize=(14, 5),sharey=True)

# show the input
axs[0].imshow(in_dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=-1, vmax=10)
axs[0].annotate('Input slope image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[0].set_facecolor('black')

axs[1].imshow(dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=-1, vmax=10)
axs[1].annotate('Flat-fielded slope image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[1].set_facecolor('black')

axs[2].imshow(in_dm.data / dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=0.98, vmax=1.02)
axs[2].annotate('Ratio image (flat field)', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[2].set_facecolor('black')

plt.tight_layout()
plt.show()
# Out:
# 2019-01-31 16:31:16,403 - stpipe - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in true_divide
#   from ipykernel import kernelapp as app
#
# 2019-01-31 16:31:16,404 - stpipe - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in true_divide
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## SRCTYPE step =======================================
# This step checks or sets whether a spectroscopic source should be treated as a point or extended object, writing the appropriate value to a keyword. Allowable values are POINT, EXTENDED and UNKNOWN. This will usually be set from the APT by an observer. If the user sets UNKNOWN, a default of EXTENDED is set for the MRS. See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/srctype/index.html

# %% [markdown]
# ### SRCTYPE: load module and show options

# %%
# import the step
from jwst.srctype import srctype_step

# print the description and options
print(srctype_step.SourceTypeStep.__doc__)
print(srctype_step.SourceTypeStep.spec)
# Out:
#     SourceTypeStep: Selects and sets a source type based on various inputs.
#     The source type is used in later calibrations to determine the appropriate
#     methods to use. Input comes from either the SRCTYPE keyword value, which
#     is populated from user info in the APT, or the NIRSpec MSA planning tool.

# %% [markdown]
# ### SRCTYPE: run step

# %%
# run the srctype step
dm = srctype_step.SourceTypeStep.call(dm, save_results=True, output_use_model=True, 
                                      output_dir=output_dir)
# Out:
# 2019-01-31 16:31:16,867 - stpipe.SourceTypeStep - INFO - SourceTypeStep instance created.
# 2019-01-31 16:31:17,065 - stpipe.SourceTypeStep - INFO - Step SourceTypeStep running with args (<IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_flatfieldstep.fits>,).
# 2019-01-31 16:31:17,099 - stpipe.SourceTypeStep - INFO - Input EXP_TYPE is MIR_MRS
# 2019-01-31 16:31:17,100 - stpipe.SourceTypeStep - INFO - Using input SRCTYPE of POINT
# 2019-01-31 16:31:18,597 - stpipe.SourceTypeStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_sourcetypestep.fits
# 2019-01-31 16:31:18,597 - stpipe.SourceTypeStep - INFO - Step SourceTypeStep done

# %% [markdown]
# ### SRCTYPE: check the SRCTYPE keyword value

# %%
# print the value of the srctype keyword
print("SRCTYPE: %s" % dm.meta.target.source_type)
# Out:
# SRCTYPE: POINT

# %% [markdown]
#  ## STRAYLIGHT step ===========================================
#
# This step performs a straylight correction using a mask file. Straylight has only been detected for MIRI MRS short wavelength channel and only this is corrected. See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/straylight/index.html
#
# Note that MIRISim does not simulate straylight so we will skip this step

# %% [markdown]
# ### STRAYLIGHT: load module and show options

# %%
from jwst.straylight import straylight_step

print(straylight_step.StraylightStep.__doc__)
print(straylight_step.StraylightStep.spec)

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     StraylightStep: Performs straylight correction image using a Mask file.
#
#
#          method = option('Nearest','ModShepard',default='ModShepard') #Algorithm method
#          roi = float(default = 50.0) # Region of interest
#          power = float(default = 1.0) # Power of weighting function

# %% [markdown]
# ### STRAYLIGHT: run step

# %%
dm = straylight_step.StraylightStep.call(dm, save_results=True, output_use_model=True, 
                                         output_dir=output_dir, skip=True)
# Out:
# 2019-01-31 16:31:19,537 - stpipe.StraylightStep - INFO - StraylightStep instance created.
# 2019-01-31 16:31:19,635 - stpipe.StraylightStep - INFO - Step StraylightStep running with args (<IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_sourcetypestep.fits>,).
# 2019-01-31 16:31:19,636 - stpipe.StraylightStep - INFO - Step skipped.
# 2019-01-31 16:31:19,638 - stpipe.StraylightStep - INFO - Step StraylightStep done

# %% [markdown]
# ### STRAYLIGHT: show input, output and difference image (only for SHORT channel)
#
# 1. Plot input, output and difference images

# %%
if dm.meta.cal_step.straylight == 'COMPLETE':
    # check which channel is used and proceed if SHORT
    if in_dm.meta.instrument.detector == 'MIRIFUSHORT':

        # plot--------------------------------------
        # plot the input and output images and show
        # the difference image
        # %matplotlib notebook
        from matplotlib.colors import LogNorm

        fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)

        # plot the input image
        axs[0].imshow(in_dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=-1, vmax=10)
        axs[0].annotate('input SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, 
                        fontweight='bold', color='k')

        # plot the output image
        axs[1].imshow(dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=-1, vmax=10)
        axs[1].annotate('output SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, 
                        fontweight='bold', color='k')

        # look at the difference image
        axs[2].imshow((in_dm.data - dm.data), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=0.01, vmax=100))
        axs[2].annotate('Difference image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, 
                        fontweight='bold', color='k')

        plt.tight_layout()
        plt.show()


    else: print('LONG channel used, straylight step skipped')
else:
    print('Straylight step was skipped')
# Out:
# Straylight step was skipped

# %% [markdown]
# ## FRINGE step ======================================
#
# This step applies a fringe correction to a science image using a fringe reference file. See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/fringe/index.html

# %% [markdown]
# ### FRINGE: load module and show options

# %%
from jwst.fringe import fringe_step

print(fringe_step.FringeStep.__doc__)
print(fringe_step.FringeStep.spec)

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     FringeStep: Apply fringe correction to a science image using a fringe
#     reference image.
#
#
#     pre_hooks          = string_list(default=list())
#     post_hooks         = string_list(default=list())
#     output_file        = output_file(default=None)   # File to save output to.
#     output_dir         = string(default=None)        # Directory path for output files
#     output_ext         = string(default='.fits')     # Default type of output
#     output_use_model   = boolean(default=False)      # When saving use `DataModel.meta.filename`
#     output_use_index   = boolean(default=True)       # Append index.
#     save_results       = boolean(default=False)      # Force save results
#     skip               = boolean(default=False)      # Skip this step
#     suffix             = string(default=None)        # Default suffix for output files
#     search_output_file = boolean(default=True)       # Use outputfile define in parent step
#     input_dir          = string(default=None)        # Input directory

# %% [markdown]
# ### FRINGE: run step

# %%
dm = fringe_step.FringeStep.call(dm, save_results=True, output_use_model=True, 
                                 output_dir=output_dir)
# Out:
# 2019-01-31 16:31:20,570 - stpipe.FringeStep - INFO - FringeStep instance created.
# 2019-01-31 16:31:20,658 - stpipe.FringeStep - INFO - Step FringeStep running with args (<IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_sourcetypestep.fits>,).
# 2019-01-31 16:31:20,694 - stpipe.FringeStep - INFO - Using FRINGE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits
# 2019-01-31 16:31:20,771 - stpipe.FringeStep - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-01-31 16:31:20,773 - stpipe.FringeStep - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-01-31 16:31:20,773 - stpipe.FringeStep - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-01-31 16:31:21,770 - stpipe.FringeStep - INFO - The DQ values in the reference file will NOT be used to update the    DQ values in the output DQ array.
# 2019-01-31 16:31:23,361 - stpipe.FringeStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_fringestep.fits
# 2019-01-31 16:31:23,362 - stpipe.FringeStep - INFO - Step FringeStep done

# %% [markdown]
# ### FRINGE: show input, output and difference image
#
# 1. Plot input, output
# 2. Plot the ratio image

# %%
# plot--------------------------------------
fig, axs = plt.subplots(1, 3, figsize=(14, 5), sharey=True)

# plot the input image
axs[0].imshow(in_dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=-1, vmax=10)
axs[0].annotate('input SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, 
                fontweight='bold', color='k')

# plot the output image
axs[1].imshow(dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=-1, vmax=10)
axs[1].annotate('output SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, 
                fontweight='bold', color='k')

# look at the ratio image
axs[2].imshow((in_dm.data / dm.data), cmap='jet', interpolation='nearest', origin='lower', vmin=0.9, vmax=1.1)
axs[2].annotate('Ratio image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, 
                fontweight='bold', color='k')

plt.tight_layout()
plt.show()
# Out:
# 2019-01-31 16:31:23,423 - stpipe - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in true_divide
#   from ipykernel import kernelapp as app
#
# 2019-01-31 16:31:23,424 - stpipe - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in true_divide
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## PHOTOM step =======================================
# This step uses spectroscopic photometric conversion reference files to convert count rates to absolute flux units. See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/photom/index.html

# %% [markdown]
# ### PHOTOM: load module and show options

# %%
# import the step
from jwst.photom import photom_step

# print the description and options
print(photom_step.PhotomStep.__doc__)
print(photom_step.PhotomStep.spec)
# Out:
#     PhotomStep: Module for loading photometric conversion infomation from
#         reference files and attaching or applying them to the input science
#         data model
#
#
#     pre_hooks          = string_list(default=list())
#     post_hooks         = string_list(default=list())
#     output_file        = output_file(default=None)   # File to save output to.
#     output_dir         = string(default=None)        # Directory path for output files
#     output_ext         = string(default='.fits')     # Default type of output
#     output_use_model   = boolean(default=False)      # When saving use `DataModel.meta.filename`
#     output_use_index   = boolean(default=True)       # Append index.
#     save_results       = boolean(default=False)      # Force save results
#     skip               = boolean(default=False)      # Skip this step
#     suffix             = string(default=None)        # Default suffix for output files
#     search_output_file = boolean(default=True)       # Use outputfile define in parent step
#     input_dir          = string(default=None)        # Input directory

# %% [markdown]
# ### PHOTOM: run step

# %%
dm = photom_step.PhotomStep.call(dm, save_results=True, output_use_model=True, 
                                 output_dir=output_dir)
# Out:
# 2019-01-31 16:31:23,928 - stpipe.PhotomStep - INFO - PhotomStep instance created.
# 2019-01-31 16:31:24,099 - stpipe.PhotomStep - INFO - Step PhotomStep running with args (<IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_fringestep.fits>,).
# 2019-01-31 16:31:24,141 - stpipe.PhotomStep - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits
# 2019-01-31 16:31:24,146 - stpipe.PhotomStep - INFO - Using area reference file: N/A
# 2019-01-31 16:31:24,147 - stpipe.PhotomStep - INFO - Using instrument: MIRI
# 2019-01-31 16:31:24,147 - stpipe.PhotomStep - INFO -  detector: MIRIFUSHORT
# 2019-01-31 16:31:24,149 - stpipe.PhotomStep - INFO -  exp_type: MIR_MRS
# 2019-01-31 16:31:24,149 - stpipe.PhotomStep - INFO -  band: SHORT
# 2019-01-31 16:31:24,341 - stpipe.PhotomStep - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-01-31 16:31:26,066 - stpipe.PhotomStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_photomstep.fits
# 2019-01-31 16:31:26,067 - stpipe.PhotomStep - INFO - Step PhotomStep done

# %% [markdown]
# ### Review 2A and 2B calibration =======================================
#
# The level 2B file is the calibrated slope product. We can show the evolution of the data through 1B - 2A - 2B stages

# %%
# open the input and output image as jwst data models
with datamodels.open(input_files[0]) as lvl1b_dm:

    # plot--------------------------------------
    # show the input ramp image and the calibrated
    # slope image.
    fig, axs = plt.subplots(1, 3, figsize=(14, 5), sharey=True)

    # 1B image
    axs[0].imshow(lvl1b_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', 
                  norm=LogNorm(vmin=1e4,vmax=2e4))
    axs[0].annotate('Level 1B', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, 
                    fontweight='bold', color='k')
    axs[0].set_facecolor('black')

    # 2A image
    axs[1].imshow(level2A_dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=-1, vmax=20)
    axs[1].annotate('Level 2A', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, 
                    fontweight='bold', color='k')
    axs[1].set_facecolor('black')

    # 2B image
    axs[2].imshow(dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=-1, vmax=1e2)
    axs[2].annotate('Level 2B', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, 
                    fontweight='bold', color='k')
    axs[2].set_facecolor('black')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## CUBE_BUILD step ======================================
# This step builds a cube from the level 2B file See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/cube_build/index.html

# %% [markdown]
# ### CUBE_BUILD: load module and show options

# %%
# import the step
from jwst.cube_build import cube_build_step

# print the description and options
print(cube_build_step.CubeBuildStep.__doc__)
print(cube_build_step.CubeBuildStep.spec)
# Out:
#     CubeBuildStep: Creates a 3-D spectral cube from a given association, single model,
#     single input file, or model container.
#     Input parameters allow the spectral cube to be built from a provided
#     channel/subchannel (MIRI) or grating/filer  (NIRSPEC)
#
#
#          channel = option('1','2','3','4','ALL','all',default='ALL') # Options: 1,2,3,4,or All
#          band = option('SHORT','MEDIUM','LONG','ALL','short','medium','long','all',default='ALL') # Options: SHORT,MEDIUM,LONG, or ALL
#          grating   = option('PRISM','G140M','G140H','G235M','G235H',G395M','G395H','ALL','all',default='ALL')  # Options: PRISM,G140M,G140H,G235M,G235H,G395M,G395H, or ALL
#          filter   = option('CLEAR','F100LP','F070LP','F170LP','F290LP','ALL','all',default='ALL') # Options: CLEAR,F100LP,F070LP,F170LP,F290LP, or ALL
#          scale1 = float(default=0.0) # cube sample size to use for axis 1, arc seconds
#          scale2 = float(default=0.0) # cube sample size to use for axis 2, arc seconds
#          scalew = float(default=0.0) # cube sample size to use for axis 3, microns
#          weighting = option('msm','miripsf','area','MSM','MIRIPSF','AREA',default = 'msm') # Type of weighting function,
#          coord_system = option('ra-dec','alpha-beta','ALPHA-BETA',default='ra-dec') # Output Coordinate system. Options: ra-dec or alpha-beta
#          rois = float(default=0.0) # region of interest spatial size, arc seconds
#          roiw = float(default=0.0) # region of interest wavelength size, microns
#          weight_power = float(default=2.0) # Weighting option to use for Modified Shepard Method
#          offset_list = string(default='NA')  # A file for dithered data containing additional ra and dec offsets
#          wavemin = float(default=None)  # Minimum wavelength to be used in the IFUCube
#          wavemax = float(default=None)  # Maximum wavelength to be used in the IFUCube
#          xdebug = integer(default=None) # debug option, x spaxel value to report information on
#          ydebug = integer(default=None) # debug option, y spaxel value to report information on
#          zdebug = integer(default=None) # debug option, z spaxel value to report  information on
#          single = boolean(default=false) # Internal pipeline option used by mrs_imatch and outlier detection
#          output_type = option('band','channel','grating','multi',default='band') # Type IFUcube to create. Options=band,channel,grating,multi
#          search_output_file = boolean(default=false)
#          output_use_model = boolean(default=true) # Use filenames in the output models

# %% [markdown]
# ### CUBE_BUILD: show some observation parameters in case user wants to set options

# %%
# show observation parameters
print("detector: %s" % dm.meta.instrument.detector)
print("channel: %s" % dm.meta.instrument.channel)
print("band: %s" % dm.meta.instrument.band)
# Out:
# detector: MIRIFUSHORT
# channel: 12
# band: SHORT

# %% [markdown]
# ### CUBE_BUILD: run step
# We will select to build a cube from channel 1 only to avoid large gaps in the wavelength direction between channels 1 and 2.

# %%
# run cube_build step
cube_dm = cube_build_step.CubeBuildStep.call(dm, channel='1', band='SHORT', 
                                             save_results=True, output_use_model=True, output_dir=output_dir)
# Out:
# 2019-01-31 16:37:10,495 - stpipe.CubeBuildStep - INFO - CubeBuildStep instance created.
# 2019-01-31 16:37:10,616 - stpipe.CubeBuildStep - INFO - Step CubeBuildStep running with args (<IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_photomstep.fits>,).
# 2019-01-31 16:37:10,617 - stpipe.CubeBuildStep - INFO - Starting IFU Cube Building Step
# 2019-01-31 16:37:10,618 - stpipe.CubeBuildStep - INFO - Input interpolation: pointcloud
# 2019-01-31 16:37:10,618 - stpipe.CubeBuildStep - INFO - Coordinate system to use: ra-dec
# 2019-01-31 16:37:10,619 - stpipe.CubeBuildStep - INFO - Weighting method for point cloud: msm
# 2019-01-31 16:37:10,620 - stpipe.CubeBuildStep - INFO - Power Weighting distance : 2.000000
# 2019-01-31 16:37:10,690 - stpipe.CubeBuildStep - INFO - The desired cubes covers the MIRI Channels: ['1']
# 2019-01-31 16:37:10,691 - stpipe.CubeBuildStep - INFO - The desired cubes covers the MIRI subchannels: ['SHORT']
# 2019-01-31 16:37:10,692 - stpipe.CubeBuildStep - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits
# 2019-01-31 16:37:13,792 - stpipe.CubeBuildStep - INFO -  The user has selected the type of IFU cube to make
# 2019-01-31 16:37:13,793 - stpipe.CubeBuildStep - INFO - Number of IFUCubes produced by a this run 1
# 2019-01-31 16:37:13,799 - stpipe.CubeBuildStep - INFO - Increasing spatial region of interest default value set for 4 dithers 0.150000
# 2019-01-31 16:37:13,800 - stpipe.CubeBuildStep - INFO - Region of interest spatial, wavelength  0.150000 0.001000
# 2019-01-31 16:37:13,801 - stpipe.CubeBuildStep - INFO - Number of bands in cube  1
# 2019-01-31 16:37:14,417 - stpipe.CubeBuildStep - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/gwcs/selector.py:444: RuntimeWarning: invalid value encountered in less_equal
#   temp = np.where(np.logical_or(temp <= val_range[0],
#
# 2019-01-31 16:37:14,419 - stpipe.CubeBuildStep - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/gwcs/selector.py:445: RuntimeWarning: invalid value encountered in greater_equal
#   temp >= val_range[1]),
#
# 2019-01-31 16:37:14,569 - stpipe.CubeBuildStep - INFO - Ra average 0.00026912.8
# 2019-01-31 16:37:14,571 - stpipe.CubeBuildStep - INFO - Cube Geometry:
# 2019-01-31 16:37:14,571 - stpipe.CubeBuildStep - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2019-01-31 16:37:14,572 - stpipe.CubeBuildStep - INFO - Axis 1    34  18.00   0.00026940   0.13000000  -2.27499992   2.27499992
# 2019-01-31 16:37:14,573 - stpipe.CubeBuildStep - INFO - Axis 2    32  17.00   0.00007355   0.13000000  -2.14499992   2.14499992
# 2019-01-31 16:37:14,573 - stpipe.CubeBuildStep - INFO - Axis 3   929   1.00   4.84761370   0.00100000   4.84761370   5.77661375
# 2019-01-31 16:37:14,574 - stpipe.CubeBuildStep - INFO - Cube covers channel, subchannel: 1 SHORT
# 2019-01-31 16:37:14,575 - stpipe.CubeBuildStep - INFO - Output Name MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_photomstep_ch1-short_s3d.fits
# 2019-01-31 16:37:59,579 - stpipe.CubeBuildStep - INFO - Time Map All slices on Detector to Cube = 43.0.s
# 2019-01-31 16:38:00,566 - stpipe.CubeBuildStep - INFO - Time to interpolate at spaxel values = 1.0.s
# 2019-01-31 16:38:00,567 - stpipe.CubeBuildStep - INFO - Time to find Cube Flux= 1.0.s
# 2019-01-31 16:38:01,473 - stpipe.CubeBuildStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_photomstep_ch1-short_s3d.fits
# 2019-01-31 16:38:01,474 - stpipe.CubeBuildStep - INFO - Step CubeBuildStep done

# %% [markdown]
# ### CUBE_BUILD: show output cube

# %%
# plot--------------------------------------
# sum the frames of the first integration and plot
# Note the user may have to adjust the scaling
# parameters
fig, axs = plt.subplots(1, 1, figsize=(8, 8))

axs.imshow(np.sum(cube_dm[0].data, axis=0), cmap='jet', interpolation='nearest', origin='lower', 
           norm=LogNorm(vmin=1e1,vmax=1e4))
axs.annotate('Collapsed cube', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, 
             fontweight='bold', color='k')
axs.set_facecolor('black')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## EXTRACT_1D step ======================================
# This step extracts a 1D spectrum from the cube. See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/extract_1d/index.html
#
# Note that since the source_type step above should have set SRCTYPE to 'EXTENDED', the extract_1d step will use an rectangular extraction region with default values. The aperture centre is at pixel x/2, y/2, the width and height are x/2 and y/2, respectively. In the future, more advanced extraction methods are planned. One can set also the aperture properties using a custom aperture reference file. Please contact pkavanagh@cp.dias.ie if you want to do this.

# %% [markdown]
# ### EXTRACT_1D: load module and show options

# %%
# import the step
from jwst.extract_1d import extract_1d_step

# print the description and options
print(extract_1d_step.Extract1dStep.__doc__)
print(extract_1d_step.Extract1dStep.spec)
# Out:
#     Extract1dStep: Extract a 1-d spectrum from 2-d data
#
#
#     # Boxcar smoothing width for background regions.
#     smoothing_length = integer(default=None)
#     # Order of polynomial fit to one column (or row if the dispersion
#     # direction is vertical) of background regions.
#     bkg_order = integer(default=None, min=0)
#     # Log a progress message when processing multi-integration data.
#     log_increment = integer(default=50)

# %% [markdown]
# ### EXTRACT_1D: run step

# %%
spec_dm = extract_1d_step.Extract1dStep.call(cube_dm, save_results=True, output_use_model=True, 
                                             output_dir=output_dir)
# Out:
# 2019-01-31 16:39:37,531 - stpipe.Extract1dStep - INFO - Extract1dStep instance created.
# 2019-01-31 16:39:37,651 - stpipe.Extract1dStep - INFO - Step Extract1dStep running with args (<ModelContainer>,).
# 2019-01-31 16:39:37,658 - stpipe.Extract1dStep - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2019-01-31 16:39:37,708 - stpipe.Extract1dStep - INFO - source_type = point
# 2019-01-31 16:39:40,482 - stpipe.Extract1dStep - INFO - Data have been flux calibrated; setting net to 0.
# 2019-01-31 16:39:40,560 - stpipe.Extract1dStep - WARNING - INTSTART not found; assuming a value of 1.
# 2019-01-31 16:39:40,561 - stpipe.Extract1dStep - WARNING - INTEND not found; assuming a value of 2.
# 2019-01-31 16:39:40,562 - stpipe.Extract1dStep - WARNING - There is no INT_TIMES table in the input file.
# 2019-01-31 16:39:40,656 - stpipe.Extract1dStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_photomstep_ch1-short_extract1dstep.fits
# 2019-01-31 16:39:40,657 - stpipe.Extract1dStep - INFO - Step Extract1dStep done

# %% [markdown]
# ### EXTRACT_1D: plot spectrum
#
# The extracted spectra are in units of mJy/arcsec^2. To convert these to mJy we multiply by the spaxel area. We also correct for the MIRISim beginning of life transmission factor. Note that an additional correction for the encircled energy in the aperture using the PSF CDP is also required but we forego this here.
#
# Note that the flux levels are lower than they should be since the centre of the extraction region is not actually located on the source in the cube of a single dither.

# %%
# plot--------------------------------------
# simple XY plot of the spectrum
fig, axs = plt.subplots(1, 1, figsize=(10, 7))

spec = spec_dm.spec[0]

spaxel_area = cube_dm[0].meta.wcsinfo.cdelt1 * cube_dm[0].meta.wcsinfo.cdelt2 * 3600**2
axs.plot(spec.spec_table['WAVELENGTH'], spec.spec_table['FLUX'] * spaxel_area * 1.2, c='b', 
         marker='.', markersize=0, linestyle='-', linewidth=2)
axs.set_ylabel(r'Flux (mJy)')
axs.set_xlabel(r'Wavelength ($\mu$m)')

plt.show()

# %% [markdown]
# ## BRING DITHERS TO LEVEL 2B FOR LEVEL 3 PROCESSING

# %%
from jwst.pipeline import Detector1Pipeline
from jwst.pipeline import Spec2Pipeline

for input_file in input_files:
    with datamodels.open(input_file) as dm_1B:
        dm_2A = Detector1Pipeline.call(dm_1B, save_results=True, output_dir=output_dir, output_use_model=True, 
                                   steps={'refpix':{'skip':True}, 'ipc':{'skip':True}})
        dm_2B = Spec2Pipeline.call(dm_2A, save_results=True, output_dir=output_dir, output_use_model=True,
                                   steps={'straylight':{'skip':True},'cube_build':{'save_results':True},
                                          'extract_1d':{'save_results':True}})
# Out:
# 2019-01-31 16:41:06,545 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2019-01-31 16:41:06,547 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2019-01-31 16:41:06,549 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2019-01-31 16:41:06,550 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2019-01-31 16:41:06,552 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2019-01-31 16:41:06,554 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2019-01-31 16:41:06,556 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2019-01-31 16:41:06,558 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2019-01-31 16:41:06,559 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2019-01-31 16:41:06,561 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2019-01-31 16:41:06,563 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2019-01-31 16:41:06,566 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2019-01-31 16:41:06,568 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2019-01-31 16:41:06,572 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2019-01-31 16:41:06,576 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2019-01-31 16:41:06,577 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2019-01-31 16:41:06,695 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args (<MIRIRampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:41:06,729 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2019-01-31 16:41:06,742 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0056.fits'.
# 2019-01-31 16:41:06,743 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2019-01-31 16:41:06,745 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits'.
# 2019-01-31 16:41:06,748 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0022.fits'.
# 2019-01-31 16:41:06,750 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2019-01-31 16:41:06,751 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits'.
# 2019-01-31 16:41:06,752 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0007.fits'.
# 2019-01-31 16:41:06,753 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0023.fits'.
# 2019-01-31 16:41:06,755 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2019-01-31 16:41:06,755 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2019-01-31 16:41:06,756 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2019-01-31 16:41:06,757 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2019-01-31 16:41:06,905 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:41:06,932 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES={} is a power of 2; correction not needed
# 2019-01-31 16:41:06,933 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2019-01-31 16:41:06,934 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2019-01-31 16:41:07,044 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:41:07,083 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0022.fits
# 2019-01-31 16:41:07,615 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2019-01-31 16:41:07,751 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:41:07,812 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0023.fits
# 2019-01-31 16:41:08,792 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2019-01-31 16:41:08,882 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:41:08,882 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2019-01-31 16:41:08,883 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2019-01-31 16:41:08,976 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:41:09,017 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits
# 2019-01-31 16:41:10,568 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2019-01-31 16:41:10,660 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:41:10,706 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0007.fits
# 2019-01-31 16:42:35,393 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2019-01-31 16:42:36,034 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:42:37,780 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2019-01-31 16:42:37,927 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:42:38,441 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2019-01-31 16:42:38,585 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:42:38,778 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0056.fits
# 2019-01-31 16:42:38,960 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=2, ngroups=50, nframes=1, groupgap=0
# 2019-01-31 16:42:38,961 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=200, nframes=1, groupgap=0
# 2019-01-31 16:42:50,603 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2019-01-31 16:42:50,891 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:42:50,893 - stpipe.Detector1Pipeline.refpix - INFO - Step skipped.
# 2019-01-31 16:42:50,897 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2019-01-31 16:42:51,107 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:42:51,329 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2019-01-31 16:42:51,343 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2019-01-31 16:42:51,417 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2019-01-31 16:42:52,836 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2019-01-31 16:42:53,764 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 1
# 2019-01-31 16:42:58,915 - stpipe.Detector1Pipeline.jump - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/jump/twopoint_difference.py:83: RuntimeWarning: invalid value encountered in sqrt
#   poisson_noise = np.sqrt(np.abs(med_diffs))
#
# 2019-01-31 16:43:15,542 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 2
# 2019-01-31 16:43:32,484 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2019-01-31 16:43:32,593 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:43:32,642 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2019-01-31 16:43:32,671 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2019-01-31 16:43:32,769 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2019-01-31 16:43:32,770 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2019-01-31 16:43:32,773 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all final groups flagged as DO_NOT_USE.
# 2019-01-31 16:43:32,775 - stpipe.Detector1Pipeline.ramp_fit - INFO - Effective integration time per group: 2.77504
# 2019-01-31 16:48:20,441 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:391: RuntimeWarning: divide by zero encountered in true_divide
#   inv_var_p4[num_int, :, :, :] = 1./var_p4[num_int, :, :, :]
#
# 2019-01-31 16:48:20,916 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:395: RuntimeWarning: divide by zero encountered in true_divide
#   var_p3[num_int, :, :] = 1./ s_inv_var_p3[num_int, :, :]
#
# 2019-01-31 16:48:23,110 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:457: RuntimeWarning: divide by zero encountered in true_divide
#   var_both3[num_int, :, :] = 1./s_inv_var_both3[num_int, :, :]
#
# 2019-01-31 16:48:30,059 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:487: RuntimeWarning: divide by zero encountered in true_divide
#   slope_dataset2 = s_slope_by_var2/s_inv_var_both2
#
# 2019-01-31 16:48:30,474 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:494: RuntimeWarning: divide by zero encountered in true_divide
#   slope_int = the_num/the_den
#
# 2019-01-31 16:48:30,474 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:494: RuntimeWarning: invalid value encountered in true_divide
#   slope_int = the_num/the_den
#
# 2019-01-31 16:48:30,504 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:505: RuntimeWarning: divide by zero encountered in true_divide
#   var_p2 = 1/(s_inv_var_p3.sum(axis=0))
#
# 2019-01-31 16:49:40,849 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:666: RuntimeWarning: invalid value encountered in sqrt
#   cubemod.err = np.sqrt(var_both3)
#
# 2019-01-31 16:49:40,878 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 50
# 2019-01-31 16:49:40,879 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2019-01-31 16:49:41,609 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2019-01-31 16:49:41,914 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:49:41,980 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2019-01-31 16:49:41,981 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2019-01-31 16:49:41,983 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2019-01-31 16:49:42,072 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(2, 1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:49:42,230 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2019-01-31 16:49:42,231 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2019-01-31 16:49:42,233 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2019-01-31 16:49:42,480 - stpipe.Detector1Pipeline - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_rateints.fits
# 2019-01-31 16:49:42,481 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2019-01-31 16:49:42,673 - stpipe.Detector1Pipeline - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits
# 2019-01-31 16:49:42,674 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2019-01-31 16:49:42,695 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2019-01-31 16:49:42,706 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2019-01-31 16:49:42,708 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2019-01-31 16:49:42,710 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2019-01-31 16:49:42,714 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2019-01-31 16:49:42,716 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2019-01-31 16:49:42,718 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2019-01-31 16:49:42,721 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2019-01-31 16:49:42,725 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2019-01-31 16:49:42,729 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2019-01-31 16:49:42,731 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2019-01-31 16:49:42,733 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2019-01-31 16:49:42,735 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2019-01-31 16:49:42,737 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2019-01-31 16:49:42,739 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2019-01-31 16:49:42,741 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2019-01-31 16:49:42,846 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args (<IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 16:49:42,878 - stpipe.Spec2Pipeline - INFO - Prefetching reference files for dataset: 'det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits' reftypes = ['area', 'barshadow', 'camera', 'collimator', 'cubepar', 'dflat', 'disperser', 'distortion', 'drizpars', 'extract1d', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'fringe', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'msaoper', 'ote', 'pathloss', 'photom', 'regions', 'resol', 'sflat', 'specwcs', 'wavecorr', 'wavelengthrange', 'wfssbkg']
# 2019-01-31 16:49:42,890 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2019-01-31 16:49:42,891 - stpipe.Spec2Pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2019-01-31 16:49:42,891 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2019-01-31 16:49:42,892 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2019-01-31 16:49:42,893 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits'.
# 2019-01-31 16:49:42,894 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2019-01-31 16:49:42,895 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2019-01-31 16:49:42,895 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf'.
# 2019-01-31 16:49:42,897 - stpipe.Spec2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2019-01-31 16:49:42,898 - stpipe.Spec2Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json'.
# 2019-01-31 16:49:42,899 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2019-01-31 16:49:42,900 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2019-01-31 16:49:42,901 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0248.fits'.
# 2019-01-31 16:49:42,902 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2019-01-31 16:49:42,903 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2019-01-31 16:49:42,903 - stpipe.Spec2Pipeline - INFO - Prefetch for FRINGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits'.
# 2019-01-31 16:49:42,905 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2019-01-31 16:49:42,906 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2019-01-31 16:49:42,906 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2019-01-31 16:49:42,907 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2019-01-31 16:49:42,908 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2019-01-31 16:49:42,908 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2019-01-31 16:49:42,909 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is 'N/A'.
# 2019-01-31 16:49:42,910 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits'.
# 2019-01-31 16:49:42,912 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_regions_0016.asdf'.
# 2019-01-31 16:49:42,914 - stpipe.Spec2Pipeline - INFO - Prefetch for RESOL reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2019-01-31 16:49:42,916 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2019-01-31 16:49:42,917 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf'.
# 2019-01-31 16:49:42,918 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVECORR reference file is 'N/A'.
# 2019-01-31 16:49:42,919 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_wavelengthrange_0003.asdf'.
# 2019-01-31 16:49:42,920 - stpipe.Spec2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2019-01-31 16:49:42,921 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2019-01-31 16:49:42,931 - stpipe.Spec2Pipeline - INFO - Processing product det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate
# 2019-01-31 16:49:42,932 - stpipe.Spec2Pipeline - INFO - Working on input <IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits> ...
# 2019-01-31 16:49:43,148 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 16:49:55,214 - stpipe.Spec2Pipeline.assign_wcs - INFO - assign_wcs did not update S_REGION for type MIR_MRS
# 2019-01-31 16:49:55,215 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2019-01-31 16:49:55,219 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2019-01-31 16:49:55,370 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 16:49:55,468 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-01-31 16:49:56,405 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2019-01-31 16:49:56,574 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 16:49:56,610 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2019-01-31 16:49:56,611 - stpipe.Spec2Pipeline.srctype - INFO - Using input SRCTYPE of POINT
# 2019-01-31 16:49:56,614 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2019-01-31 16:49:56,756 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 16:49:56,757 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2019-01-31 16:49:56,759 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2019-01-31 16:49:56,885 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 16:49:56,918 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits
# 2019-01-31 16:49:56,981 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-01-31 16:49:56,982 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-01-31 16:49:56,983 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-01-31 16:49:58,000 - stpipe.Spec2Pipeline.fringe - INFO - The DQ values in the reference file will NOT be used to update the    DQ values in the output DQ array.
# 2019-01-31 16:49:58,003 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2019-01-31 16:49:58,150 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 16:49:58,194 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits
# 2019-01-31 16:49:58,197 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2019-01-31 16:49:58,198 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2019-01-31 16:49:58,198 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIFUSHORT
# 2019-01-31 16:49:58,199 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_MRS
# 2019-01-31 16:49:58,200 - stpipe.Spec2Pipeline.photom - INFO -  band: SHORT
# 2019-01-31 16:49:58,376 - stpipe.Spec2Pipeline.photom - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-01-31 16:49:58,391 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2019-01-31 16:49:58,509 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<IFUImageModel(1024, 1032) from det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 16:49:58,510 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2019-01-31 16:49:58,511 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: pointcloud
# 2019-01-31 16:49:58,512 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: ra-dec
# 2019-01-31 16:49:58,513 - stpipe.Spec2Pipeline.cube_build - INFO - Weighting method for point cloud: msm
# 2019-01-31 16:49:58,513 - stpipe.Spec2Pipeline.cube_build - INFO - Power Weighting distance : 2.000000
# 2019-01-31 16:49:58,585 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI Channels: ['1', '2']
# 2019-01-31 16:49:58,586 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI subchannels: ['SHORT', 'SHORT']
# 2019-01-31 16:49:58,588 - stpipe.Spec2Pipeline.cube_build - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits
# 2019-01-31 16:50:01,448 - stpipe.Spec2Pipeline.cube_build - INFO - Output IFUcube are constructed from all the data
# 2019-01-31 16:50:01,450 - stpipe.Spec2Pipeline.cube_build - INFO - Number of IFUCubes produced by a this run 1
# 2019-01-31 16:50:01,453 - stpipe.Spec2Pipeline.cube_build - INFO - Increasing spatial region of interest default value set for 4 dithers 0.150000
# 2019-01-31 16:50:01,454 - stpipe.Spec2Pipeline.cube_build - INFO - Region of interest spatial, wavelength  0.150000 0.001000
# 2019-01-31 16:50:01,454 - stpipe.Spec2Pipeline.cube_build - INFO - Number of bands in cube  2
# 2019-01-31 16:50:02,010 - stpipe.Spec2Pipeline.cube_build - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/gwcs/selector.py:444: RuntimeWarning: invalid value encountered in less_equal
#   temp = np.where(np.logical_or(temp <= val_range[0],
#
# 2019-01-31 16:50:02,012 - stpipe.Spec2Pipeline.cube_build - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/gwcs/selector.py:445: RuntimeWarning: invalid value encountered in greater_equal
#   temp >= val_range[1]),
#
# 2019-01-31 16:50:02,834 - stpipe.Spec2Pipeline.cube_build - INFO - Ra average 0.00025312.8
# 2019-01-31 16:50:02,838 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2019-01-31 16:50:02,839 - stpipe.Spec2Pipeline.cube_build - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2019-01-31 16:50:02,839 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    42  22.00   0.00025316   0.13000000  -2.79499990   2.79499990
# 2019-01-31 16:50:02,840 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    40  21.00  -0.00001188   0.13000000  -2.66499990   2.66499990
# 2019-01-31 16:50:02,841 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  4029   1.00   4.84778546   0.00100000   4.84778546   8.87678565
# 2019-01-31 16:50:02,842 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 1 SHORT
# 2019-01-31 16:50:02,843 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 2 SHORT
# 2019-01-31 16:50:02,843 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name det_image_seq2_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2019-01-31 16:51:45,750 - stpipe.Spec2Pipeline.cube_build - INFO - Time Map All slices on Detector to Cube = 92.9.s
# 2019-01-31 16:51:49,960 - stpipe.Spec2Pipeline.cube_build - INFO - Time to interpolate at spaxel values = 4.2.s
# 2019-01-31 16:51:49,961 - stpipe.Spec2Pipeline.cube_build - INFO - Time to find Cube Flux= 4.2.s
# 2019-01-31 16:51:53,276 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2019-01-31 16:51:53,764 - stpipe.Spec2Pipeline - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2019-01-31 16:51:53,985 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<ModelContainer>,).
# 2019-01-31 16:51:53,992 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2019-01-31 16:51:54,029 - stpipe.Spec2Pipeline.extract_1d - INFO - source_type = point
# 2019-01-31 16:52:05,478 - stpipe.Spec2Pipeline.extract_1d - INFO - Data have been flux calibrated; setting net to 0.
# 2019-01-31 16:52:05,547 - stpipe.Spec2Pipeline.extract_1d - WARNING - INTSTART not found; assuming a value of 1.
# 2019-01-31 16:52:05,548 - stpipe.Spec2Pipeline.extract_1d - WARNING - INTEND not found; assuming a value of 2.
# 2019-01-31 16:52:05,548 - stpipe.Spec2Pipeline.extract_1d - WARNING - There is no INT_TIMES table in the input file.
# 2019-01-31 16:52:05,630 - stpipe.Spec2Pipeline.extract_1d - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_x1d.fits
# 2019-01-31 16:52:05,631 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2019-01-31 16:52:05,632 - stpipe.Spec2Pipeline - INFO - Finished processing product det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate
# 2019-01-31 16:52:07,116 - stpipe.Spec2Pipeline - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_cal.fits
# 2019-01-31 16:52:07,337 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2019-01-31 16:52:07,340 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# 2019-01-31 16:52:07,495 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2019-01-31 16:52:07,499 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2019-01-31 16:52:07,502 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2019-01-31 16:52:07,504 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2019-01-31 16:52:07,506 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2019-01-31 16:52:07,508 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2019-01-31 16:52:07,510 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2019-01-31 16:52:07,511 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2019-01-31 16:52:07,514 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2019-01-31 16:52:07,517 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2019-01-31 16:52:07,519 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2019-01-31 16:52:07,522 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2019-01-31 16:52:07,524 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2019-01-31 16:52:07,526 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2019-01-31 16:52:07,528 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2019-01-31 16:52:07,530 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2019-01-31 16:52:07,673 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args (<MIRIRampModel(2, 50, 1024, 1032) from det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:52:07,715 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2019-01-31 16:52:07,723 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0056.fits'.
# 2019-01-31 16:52:07,724 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2019-01-31 16:52:07,725 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits'.
# 2019-01-31 16:52:07,726 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0022.fits'.
# 2019-01-31 16:52:07,727 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2019-01-31 16:52:07,728 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits'.
# 2019-01-31 16:52:07,729 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0007.fits'.
# 2019-01-31 16:52:07,729 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0023.fits'.
# 2019-01-31 16:52:07,730 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2019-01-31 16:52:07,731 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2019-01-31 16:52:07,732 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2019-01-31 16:52:07,733 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2019-01-31 16:52:07,866 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:52:07,899 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES={} is a power of 2; correction not needed
# 2019-01-31 16:52:07,900 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2019-01-31 16:52:07,901 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2019-01-31 16:52:08,014 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:52:08,049 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0022.fits
# 2019-01-31 16:52:10,904 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2019-01-31 16:52:11,006 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:52:11,039 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0023.fits
# 2019-01-31 16:52:11,936 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2019-01-31 16:52:12,068 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:52:12,069 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2019-01-31 16:52:12,070 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2019-01-31 16:52:12,198 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:52:12,266 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits
# 2019-01-31 16:52:14,006 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2019-01-31 16:52:14,126 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:52:14,160 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0007.fits
# 2019-01-31 16:53:23,894 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2019-01-31 16:53:24,018 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:53:25,086 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2019-01-31 16:53:25,197 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:53:25,498 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2019-01-31 16:53:25,619 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:53:25,734 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0056.fits
# 2019-01-31 16:53:25,872 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=2, ngroups=50, nframes=1, groupgap=0
# 2019-01-31 16:53:25,873 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=200, nframes=1, groupgap=0
# 2019-01-31 16:53:34,801 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2019-01-31 16:53:34,963 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:53:34,964 - stpipe.Detector1Pipeline.refpix - INFO - Step skipped.
# 2019-01-31 16:53:34,965 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2019-01-31 16:53:35,076 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:53:35,181 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2019-01-31 16:53:35,188 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2019-01-31 16:53:35,218 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2019-01-31 16:53:35,895 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2019-01-31 16:53:36,451 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 1
# 2019-01-31 16:53:39,722 - stpipe.Detector1Pipeline.jump - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/jump/twopoint_difference.py:83: RuntimeWarning: invalid value encountered in sqrt
#   poisson_noise = np.sqrt(np.abs(med_diffs))
#
# 2019-01-31 16:53:54,179 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 2
# 2019-01-31 16:54:11,209 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2019-01-31 16:54:11,445 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(2, 50, 1024, 1032) from det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 16:54:11,629 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2019-01-31 16:54:11,668 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2019-01-31 16:54:11,812 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2019-01-31 16:54:11,813 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2019-01-31 16:54:11,818 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all final groups flagged as DO_NOT_USE.
# 2019-01-31 16:54:11,819 - stpipe.Detector1Pipeline.ramp_fit - INFO - Effective integration time per group: 2.77504
# 2019-01-31 16:58:52,762 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:391: RuntimeWarning: divide by zero encountered in true_divide
#   inv_var_p4[num_int, :, :, :] = 1./var_p4[num_int, :, :, :]
#
# 2019-01-31 16:58:53,240 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:395: RuntimeWarning: divide by zero encountered in true_divide
#   var_p3[num_int, :, :] = 1./ s_inv_var_p3[num_int, :, :]
#
# 2019-01-31 16:58:55,393 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:457: RuntimeWarning: divide by zero encountered in true_divide
#   var_both3[num_int, :, :] = 1./s_inv_var_both3[num_int, :, :]
# 2019-01-31 16:59:01,950 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:487: RuntimeWarning: divide by zero encountered in true_divide
#   slope_dataset2 = s_slope_by_var2/s_inv_var_both2
#
# 2019-01-31 16:59:02,308 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:494: RuntimeWarning: divide by zero encountered in true_divide
#   slope_int = the_num/the_den
#
# 2019-01-31 16:59:02,309 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:494: RuntimeWarning: invalid value encountered in true_divide
#   slope_int = the_num/the_den
#
# 2019-01-31 16:59:02,337 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:505: RuntimeWarning: divide by zero encountered in true_divide
#   var_p2 = 1/(s_inv_var_p3.sum(axis=0))
#
# 2019-01-31 17:00:11,556 - stpipe.Detector1Pipeline.ramp_fit - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/jwst-0.9.6-py3.5-macosx-10.6-x86_64.egg/jwst/ramp_fitting/utils.py:666: RuntimeWarning: invalid value encountered in sqrt
#   cubemod.err = np.sqrt(var_both3)
#
# 2019-01-31 17:00:11,582 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 50
# 2019-01-31 17:00:11,583 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2019-01-31 17:00:12,140 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2019-01-31 17:00:12,464 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 17:00:12,528 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2019-01-31 17:00:12,529 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2019-01-31 17:00:12,531 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2019-01-31 17:00:12,640 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(2, 1024, 1032) from det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits>,).
# 2019-01-31 17:00:12,778 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2019-01-31 17:00:12,779 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2019-01-31 17:00:12,781 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2019-01-31 17:00:13,043 - stpipe.Detector1Pipeline - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq1_MIRIFUSHORT_12SHORTexp1_rateints.fits
# 2019-01-31 17:00:13,044 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2019-01-31 17:00:13,234 - stpipe.Detector1Pipeline - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq1_MIRIFUSHORT_12SHORTexp1_rate.fits
# 2019-01-31 17:00:13,235 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2019-01-31 17:00:13,253 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2019-01-31 17:00:13,256 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2019-01-31 17:00:13,257 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2019-01-31 17:00:13,259 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2019-01-31 17:00:13,264 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2019-01-31 17:00:13,266 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2019-01-31 17:00:13,268 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2019-01-31 17:00:13,270 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2019-01-31 17:00:13,272 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2019-01-31 17:00:13,275 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2019-01-31 17:00:13,277 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2019-01-31 17:00:13,279 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2019-01-31 17:00:13,281 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2019-01-31 17:00:13,283 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2019-01-31 17:00:13,284 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2019-01-31 17:00:13,286 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2019-01-31 17:00:13,414 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 17:00:13,445 - stpipe.Spec2Pipeline - INFO - Prefetching reference files for dataset: 'det_image_seq1_MIRIFUSHORT_12SHORTexp1_rate.fits' reftypes = ['area', 'barshadow', 'camera', 'collimator', 'cubepar', 'dflat', 'disperser', 'distortion', 'drizpars', 'extract1d', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'fringe', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'msaoper', 'ote', 'pathloss', 'photom', 'regions', 'resol', 'sflat', 'specwcs', 'wavecorr', 'wavelengthrange', 'wfssbkg']
# 2019-01-31 17:00:13,452 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2019-01-31 17:00:13,452 - stpipe.Spec2Pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2019-01-31 17:00:13,453 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2019-01-31 17:00:13,454 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2019-01-31 17:00:13,454 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits'.
# 2019-01-31 17:00:13,455 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2019-01-31 17:00:13,456 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# ...
# 2019-01-31 17:20:14,895 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2019-01-31 17:20:14,913 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2019-01-31 17:20:14,915 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2019-01-31 17:20:14,917 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2019-01-31 17:20:14,919 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2019-01-31 17:20:14,921 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2019-01-31 17:20:14,925 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2019-01-31 17:20:14,927 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2019-01-31 17:20:14,928 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2019-01-31 17:20:14,931 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2019-01-31 17:20:14,934 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2019-01-31 17:20:14,936 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2019-01-31 17:20:14,938 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2019-01-31 17:20:14,940 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2019-01-31 17:20:14,942 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2019-01-31 17:20:14,944 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2019-01-31 17:20:14,946 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2019-01-31 17:20:15,105 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args (<IFUImageModel(1024, 1032) from det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 17:20:15,137 - stpipe.Spec2Pipeline - INFO - Prefetching reference files for dataset: 'det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate.fits' reftypes = ['area', 'barshadow', 'camera', 'collimator', 'cubepar', 'dflat', 'disperser', 'distortion', 'drizpars', 'extract1d', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'fringe', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'msaoper', 'ote', 'pathloss', 'photom', 'regions', 'resol', 'sflat', 'specwcs', 'wavecorr', 'wavelengthrange', 'wfssbkg']
# 2019-01-31 17:20:15,145 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2019-01-31 17:20:15,146 - stpipe.Spec2Pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2019-01-31 17:20:15,146 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2019-01-31 17:20:15,147 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2019-01-31 17:20:15,147 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits'.
# 2019-01-31 17:20:15,148 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2019-01-31 17:20:15,149 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2019-01-31 17:20:15,149 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf'.
# 2019-01-31 17:20:15,150 - stpipe.Spec2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2019-01-31 17:20:15,151 - stpipe.Spec2Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json'.
# 2019-01-31 17:20:15,151 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2019-01-31 17:20:15,152 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2019-01-31 17:20:15,152 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0248.fits'.
# 2019-01-31 17:20:15,153 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2019-01-31 17:20:15,154 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2019-01-31 17:20:15,154 - stpipe.Spec2Pipeline - INFO - Prefetch for FRINGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits'.
# 2019-01-31 17:20:15,155 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2019-01-31 17:20:15,155 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2019-01-31 17:20:15,155 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2019-01-31 17:20:15,156 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2019-01-31 17:20:15,156 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2019-01-31 17:20:15,157 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2019-01-31 17:20:15,157 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is 'N/A'.
# 2019-01-31 17:20:15,158 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits'.
# 2019-01-31 17:20:15,158 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_regions_0016.asdf'.
# 2019-01-31 17:20:15,159 - stpipe.Spec2Pipeline - INFO - Prefetch for RESOL reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2019-01-31 17:20:15,160 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2019-01-31 17:20:15,160 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf'.
# 2019-01-31 17:20:15,161 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVECORR reference file is 'N/A'.
# 2019-01-31 17:20:15,161 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_wavelengthrange_0003.asdf'.
# 2019-01-31 17:20:15,162 - stpipe.Spec2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2019-01-31 17:20:15,162 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2019-01-31 17:20:15,164 - stpipe.Spec2Pipeline - INFO - Processing product det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate
# 2019-01-31 17:20:15,164 - stpipe.Spec2Pipeline - INFO - Working on input <IFUImageModel(1024, 1032) from det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate.fits> ...
# 2019-01-31 17:20:15,377 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<IFUImageModel(1024, 1032) from det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 17:20:27,046 - stpipe.Spec2Pipeline.assign_wcs - INFO - assign_wcs did not update S_REGION for type MIR_MRS
# 2019-01-31 17:20:27,047 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2019-01-31 17:20:27,051 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2019-01-31 17:20:27,231 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<IFUImageModel(1024, 1032) from det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 17:20:27,352 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-01-31 17:20:28,245 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2019-01-31 17:20:28,436 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<IFUImageModel(1024, 1032) from det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 17:20:28,467 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2019-01-31 17:20:28,468 - stpipe.Spec2Pipeline.srctype - INFO - Using input SRCTYPE of POINT
# 2019-01-31 17:20:28,469 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2019-01-31 17:20:28,638 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<IFUImageModel(1024, 1032) from det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 17:20:28,640 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2019-01-31 17:20:28,641 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2019-01-31 17:20:28,801 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<IFUImageModel(1024, 1032) from det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 17:20:28,835 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits
# 2019-01-31 17:20:28,918 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-01-31 17:20:28,919 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-01-31 17:20:28,920 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-01-31 17:20:29,830 - stpipe.Spec2Pipeline.fringe - INFO - The DQ values in the reference file will NOT be used to update the    DQ values in the output DQ array.
# 2019-01-31 17:20:29,832 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2019-01-31 17:20:30,011 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<IFUImageModel(1024, 1032) from det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 17:20:30,068 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits
# 2019-01-31 17:20:30,071 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2019-01-31 17:20:30,071 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2019-01-31 17:20:30,072 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIFUSHORT
# 2019-01-31 17:20:30,073 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_MRS
# 2019-01-31 17:20:30,073 - stpipe.Spec2Pipeline.photom - INFO -  band: SHORT
# 2019-01-31 17:20:30,252 - stpipe.Spec2Pipeline.photom - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-01-31 17:20:30,266 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2019-01-31 17:20:30,422 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<IFUImageModel(1024, 1032) from det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate.fits>,).
# 2019-01-31 17:20:30,424 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2019-01-31 17:20:30,425 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: pointcloud
# 2019-01-31 17:20:30,425 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: ra-dec
# 2019-01-31 17:20:30,426 - stpipe.Spec2Pipeline.cube_build - INFO - Weighting method for point cloud: msm
# 2019-01-31 17:20:30,427 - stpipe.Spec2Pipeline.cube_build - INFO - Power Weighting distance : 2.000000
# 2019-01-31 17:20:30,496 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI Channels: ['1', '2']
# 2019-01-31 17:20:30,497 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI subchannels: ['SHORT', 'SHORT']
# 2019-01-31 17:20:30,498 - stpipe.Spec2Pipeline.cube_build - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits
# 2019-01-31 17:20:33,363 - stpipe.Spec2Pipeline.cube_build - INFO - Output IFUcube are constructed from all the data
# 2019-01-31 17:20:33,364 - stpipe.Spec2Pipeline.cube_build - INFO - Number of IFUCubes produced by a this run 1
# 2019-01-31 17:20:33,367 - stpipe.Spec2Pipeline.cube_build - INFO - Increasing spatial region of interest default value set for 4 dithers 0.150000
# 2019-01-31 17:20:33,368 - stpipe.Spec2Pipeline.cube_build - INFO - Region of interest spatial, wavelength  0.150000 0.001000
# 2019-01-31 17:20:33,369 - stpipe.Spec2Pipeline.cube_build - INFO - Number of bands in cube  2
# 2019-01-31 17:20:33,940 - stpipe.Spec2Pipeline.cube_build - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/gwcs/selector.py:444: RuntimeWarning: invalid value encountered in less_equal
#   temp = np.where(np.logical_or(temp <= val_range[0],
#
# 2019-01-31 17:20:33,942 - stpipe.Spec2Pipeline.cube_build - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/gwcs/selector.py:445: RuntimeWarning: invalid value encountered in greater_equal
#   temp >= val_range[1]),
#
# 2019-01-31 17:20:34,738 - stpipe.Spec2Pipeline.cube_build - INFO - Ra average 0.00028312.8
# 2019-01-31 17:20:34,744 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2019-01-31 17:20:34,745 - stpipe.Spec2Pipeline.cube_build - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2019-01-31 17:20:34,745 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    42  22.00   0.00028335   0.13000000  -2.79499990   2.79499990
# 2019-01-31 17:20:34,746 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    40  21.00   0.00000855   0.13000000  -2.66499990   2.66499990
# 2019-01-31 17:20:34,747 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  4029   1.00   4.84778546   0.00100000   4.84778546   8.87678565
# 2019-01-31 17:20:34,747 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 1 SHORT
# 2019-01-31 17:20:34,748 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 2 SHORT
# 2019-01-31 17:20:34,749 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name det_image_seq3_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2019-01-31 17:22:13,105 - stpipe.Spec2Pipeline.cube_build - INFO - Time Map All slices on Detector to Cube = 88.0.s
# 2019-01-31 17:22:17,108 - stpipe.Spec2Pipeline.cube_build - INFO - Time to interpolate at spaxel values = 4.0.s
# 2019-01-31 17:22:17,109 - stpipe.Spec2Pipeline.cube_build - INFO - Time to find Cube Flux= 4.0.s
# 2019-01-31 17:22:20,195 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2019-01-31 17:22:20,756 - stpipe.Spec2Pipeline - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq3_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2019-01-31 17:22:20,984 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<ModelContainer>,).
# 2019-01-31 17:22:20,991 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2019-01-31 17:22:21,028 - stpipe.Spec2Pipeline.extract_1d - INFO - source_type = point
# 2019-01-31 17:22:32,030 - stpipe.Spec2Pipeline.extract_1d - INFO - Data have been flux calibrated; setting net to 0.
# 2019-01-31 17:22:32,098 - stpipe.Spec2Pipeline.extract_1d - WARNING - INTSTART not found; assuming a value of 1.
# 2019-01-31 17:22:32,099 - stpipe.Spec2Pipeline.extract_1d - WARNING - INTEND not found; assuming a value of 2.
# 2019-01-31 17:22:32,100 - stpipe.Spec2Pipeline.extract_1d - WARNING - There is no INT_TIMES table in the input file.
# 2019-01-31 17:22:32,183 - stpipe.Spec2Pipeline.extract_1d - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq3_MIRIFUSHORT_12SHORTexp1_x1d.fits
# 2019-01-31 17:22:32,184 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2019-01-31 17:22:32,184 - stpipe.Spec2Pipeline - INFO - Finished processing product det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate
# 2019-01-31 17:22:33,608 - stpipe.Spec2Pipeline - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq3_MIRIFUSHORT_12SHORTexp1_cal.fits
# 2019-01-31 17:22:33,766 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2019-01-31 17:22:33,767 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done

# %%
# create and load association
cal_files = glob.glob(os.path.join(output_dir,'*_cal.fits'))
call(["asn_from_list", "-o", "MRS_asn.json"] + cal_files + ["--product-name", "dither"])
dms = datamodels.open("MRS_asn.json")

# %% [markdown]
# ## MRS_IMATCH step ======================================
# This step “matches” image intensities of several input 2D MIRI MRS images by fitting polynomials to cube intensities (cubes built from input 2D images) in such a way as to minimize inter-image mismatch in the least squares sense.  See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/mrs_imatch/index.html
#
# Note that by default this step adds the determined polynomials to each input datamodel metadata but does not subtract them from the image data. This funcitonality must be set by the user with the 'subtract' option.
#
# The subtraction appears to happen in cube_build. Unfortunately, this does not appear to be working very well at the moment so we will skip this step for now.

# %% [markdown]
# ### MRS_IMATCH: load module and show options

# %%
# import the step
from jwst.mrs_imatch import mrs_imatch_step

# print the description and options
print(mrs_imatch_step.MRSIMatchStep.__doc__)
print(mrs_imatch_step.MRSIMatchStep.spec)
# Out:
#     MRSIMatchStep: Subtraction or equalization of sky background in MIRI MRS science images.
#
#
#
#         # General sky matching parameters:
#         bkg_degree = integer(min=0, default=1) # Degree of the polynomial for background fitting
#         subtract = boolean(default=False) # subtract computed sky from 'images' cube data?

# %% [markdown]
# ### MRS_IMATCH: run step

# %%
dms = mrs_imatch_step.MRSIMatchStep.call(dms, skip=True)
# Out:
# 2019-02-01 10:17:12,609 - stpipe.MRSIMatchStep - INFO - MRSIMatchStep instance created.
# 2019-02-01 10:17:13,007 - stpipe.MRSIMatchStep - INFO - Step MRSIMatchStep running with args (<ModelContainer>,).
# 2019-02-01 10:17:42,515 - stpipe.CubeBuildStep - INFO - CubeBuildStep instance created.
# 2019-02-01 10:17:42,516 - stpipe.CubeBuildStep - INFO - Starting IFU Cube Building Step
# 2019-02-01 10:17:42,517 - stpipe.CubeBuildStep - INFO - Input interpolation: pointcloud
# 2019-02-01 10:17:42,518 - stpipe.CubeBuildStep - INFO - Coordinate system to use: ra-dec
# 2019-02-01 10:17:42,518 - stpipe.CubeBuildStep - INFO - Weighting method for point cloud: msm
# 2019-02-01 10:17:42,519 - stpipe.CubeBuildStep - INFO - Power Weighting distance : 2.000000
# 2019-02-01 10:17:42,735 - stpipe.MRSIMatchStep - INFO - The desired cubes covers the MIRI Channels: ['1']
# 2019-02-01 10:17:42,736 - stpipe.MRSIMatchStep - INFO - The desired cubes covers the MIRI subchannels: ['SHORT']
# 2019-02-01 10:17:42,737 - stpipe.MRSIMatchStep - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits
# 2019-02-01 10:17:45,517 - stpipe.MRSIMatchStep - INFO -  Single = true, creating a set of single exposures mapped to output IFUCube coordinate system
# 2019-02-01 10:17:45,518 - stpipe.CubeBuildStep - INFO - Number of IFUCubes produced by a this run 1
# 2019-02-01 10:17:45,521 - stpipe.MRSIMatchStep - INFO - Increasing spatial region of interest default value set for 4 dithers 0.150000
# 2019-02-01 10:17:45,522 - stpipe.MRSIMatchStep - INFO - Region of interest spatial, wavelength  0.150000 0.001000
# 2019-02-01 10:17:45,522 - stpipe.MRSIMatchStep - INFO - Number of bands in cube  1
# 2019-02-01 10:17:46,074 - stpipe.MRSIMatchStep - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/gwcs/selector.py:444: RuntimeWarning: invalid value encountered in less_equal
#   temp = np.where(np.logical_or(temp <= val_range[0],
#
# 2019-02-01 10:17:46,076 - stpipe.MRSIMatchStep - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/gwcs/selector.py:445: RuntimeWarning: invalid value encountered in greater_equal
#   temp >= val_range[1]),
#
# 2019-02-01 10:17:48,180 - stpipe.MRSIMatchStep - INFO - Ra average -0.00001612.8
# 2019-02-01 10:17:48,183 - stpipe.MRSIMatchStep - INFO - Cube Geometry:
# 2019-02-01 10:17:48,183 - stpipe.MRSIMatchStep - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2019-02-01 10:17:48,184 - stpipe.MRSIMatchStep - INFO - Axis 1    52  27.00  -0.00001638   0.13000000  -3.44499987   3.44499987
# 2019-02-01 10:17:48,185 - stpipe.MRSIMatchStep - INFO - Axis 2    38  20.00  -0.00000771   0.13000000  -2.53499991   2.53499991
# 2019-02-01 10:17:48,185 - stpipe.MRSIMatchStep - INFO - Axis 3   929   1.00   4.84761370   0.00100000   4.84761370   5.77661375
# 2019-02-01 10:17:48,186 - stpipe.MRSIMatchStep - INFO - Cube covers channel, subchannel: 1 SHORT
# 2019-02-01 10:18:35,704 - stpipe.MRSIMatchStep - INFO - Time to interpolate at spaxel values = 1.2.s
# 2019-02-01 10:18:35,786 - stpipe.MRSIMatchStep - INFO - Blending metadata for
# 2019-02-01 10:18:38,268 - stpipe.MRSIMatchStep - INFO - Time Create Single IFUcube  = 50.1.s
# 2019-02-01 10:19:26,154 - stpipe.MRSIMatchStep - INFO - Time to interpolate at spaxel values = 1.2.s
# 2019-02-01 10:19:26,234 - stpipe.MRSIMatchStep - INFO - Blending metadata for
# 2019-02-01 10:19:28,714 - stpipe.MRSIMatchStep - INFO - Time Create Single IFUcube  = 50.3.s
# 2019-02-01 10:20:16,469 - stpipe.MRSIMatchStep - INFO - Time to interpolate at spaxel values = 1.2.s
# 2019-02-01 10:20:16,560 - stpipe.MRSIMatchStep - INFO - Blending metadata for
# 2019-02-01 10:20:19,264 - stpipe.MRSIMatchStep - INFO - Time Create Single IFUcube  = 50.4.s
# 2019-02-01 10:21:06,446 - stpipe.MRSIMatchStep - INFO - Time to interpolate at spaxel values = 1.2.s
# 2019-02-01 10:21:06,535 - stpipe.MRSIMatchStep - INFO - Blending metadata for
# 2019-02-01 10:21:09,325 - stpipe.MRSIMatchStep - INFO - Time Create Single IFUcube  = 49.9.s
# 2019-02-01 10:21:09,448 - stpipe.CubeBuildStep - INFO - Number of IFUCube models returned from building single IFUCubes 4
# 2019-02-01 10:21:26,664 - stpipe.CubeBuildStep - INFO - CubeBuildStep instance created.
# 2019-02-01 10:21:26,665 - stpipe.CubeBuildStep - INFO - Starting IFU Cube Building Step
# 2019-02-01 10:21:26,665 - stpipe.CubeBuildStep - INFO - Input interpolation: pointcloud
# 2019-02-01 10:21:26,666 - stpipe.CubeBuildStep - INFO - Coordinate system to use: ra-dec
# 2019-02-01 10:21:26,667 - stpipe.CubeBuildStep - INFO - Weighting method for point cloud: msm
# 2019-02-01 10:21:26,667 - stpipe.CubeBuildStep - INFO - Power Weighting distance : 2.000000
# 2019-02-01 10:21:26,913 - stpipe.MRSIMatchStep - INFO - The desired cubes covers the MIRI Channels: ['2']
# 2019-02-01 10:21:26,915 - stpipe.MRSIMatchStep - INFO - The desired cubes covers the MIRI subchannels: ['SHORT']
# 2019-02-01 10:21:26,915 - stpipe.MRSIMatchStep - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits
# 2019-02-01 10:21:29,708 - stpipe.MRSIMatchStep - INFO -  Single = true, creating a set of single exposures mapped to output IFUCube coordinate system
# 2019-02-01 10:21:29,709 - stpipe.CubeBuildStep - INFO - Number of IFUCubes produced by a this run 1
# 2019-02-01 10:21:29,712 - stpipe.MRSIMatchStep - INFO - Increasing spatial region of interest default value set for 4 dithers 0.225000
# 2019-02-01 10:21:29,713 - stpipe.MRSIMatchStep - INFO - Region of interest spatial, wavelength  0.225000 0.002000
# 2019-02-01 10:21:29,714 - stpipe.MRSIMatchStep - INFO - Number of bands in cube  1
# 2019-02-01 10:21:32,582 - stpipe.MRSIMatchStep - INFO - Ra average -0.00003312.8
# 2019-02-01 10:21:32,585 - stpipe.MRSIMatchStep - INFO - Cube Geometry:
# 2019-02-01 10:21:32,585 - stpipe.MRSIMatchStep - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2019-02-01 10:21:32,586 - stpipe.MRSIMatchStep - INFO - Axis 1    46  24.00  -0.00003261   0.17000000  -3.99500004   3.99500004
# 2019-02-01 10:21:32,587 - stpipe.MRSIMatchStep - INFO - Axis 2    36  19.00  -0.00009315   0.17000000  -3.14500003   3.14500003
# 2019-02-01 10:21:32,587 - stpipe.MRSIMatchStep - INFO - Axis 3   716   1.00   7.44517473   0.00200000   7.44517473   8.87717480
# 2019-02-01 10:21:32,588 - stpipe.MRSIMatchStep - INFO - Cube covers channel, subchannel: 2 SHORT
# 2019-02-01 10:22:25,435 - stpipe.MRSIMatchStep - INFO - Time to interpolate at spaxel values = 0.8.s
# 2019-02-01 10:22:25,501 - stpipe.MRSIMatchStep - INFO - Blending metadata for
# 2019-02-01 10:22:27,817 - stpipe.MRSIMatchStep - INFO - Time Create Single IFUcube  = 55.2.s
# 2019-02-01 10:23:19,570 - stpipe.MRSIMatchStep - INFO - Time to interpolate at spaxel values = 0.9.s
# 2019-02-01 10:23:19,641 - stpipe.MRSIMatchStep - INFO - Blending metadata for
# 2019-02-01 10:23:22,218 - stpipe.MRSIMatchStep - INFO - Time Create Single IFUcube  = 54.3.s
# 2019-02-01 10:24:15,949 - stpipe.MRSIMatchStep - INFO - Time to interpolate at spaxel values = 0.8.s
# 2019-02-01 10:24:16,022 - stpipe.MRSIMatchStep - INFO - Blending metadata for
# 2019-02-01 10:24:18,561 - stpipe.MRSIMatchStep - INFO - Time Create Single IFUcube  = 56.3.s
# 2019-02-01 10:25:11,643 - stpipe.MRSIMatchStep - INFO - Time to interpolate at spaxel values = 0.8.s
# 2019-02-01 10:25:11,713 - stpipe.MRSIMatchStep - INFO - Blending metadata for
# 2019-02-01 10:25:13,978 - stpipe.MRSIMatchStep - INFO - Time Create Single IFUcube  = 55.3.s
# 2019-02-01 10:25:14,070 - stpipe.CubeBuildStep - INFO - Number of IFUCube models returned from building single IFUCubes 4
# 2019-02-01 10:25:26,286 - stpipe.MRSIMatchStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_mrsimatchstep.fits
# 2019-02-01 10:25:27,742 - stpipe.MRSIMatchStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq1_MIRIFUSHORT_12SHORTexp1_mrsimatchstep.fits
# 2019-02-01 10:25:29,240 - stpipe.MRSIMatchStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq3_MIRIFUSHORT_12SHORTexp1_mrsimatchstep.fits
# 2019-02-01 10:25:30,756 - stpipe.MRSIMatchStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq4_MIRIFUSHORT_12SHORTexp1_mrsimatchstep.fits
# 2019-02-01 10:25:30,757 - stpipe.MRSIMatchStep - INFO - Step MRSIMatchStep done

# %% [markdown]
# ### MRS_IMATCH: check background metadata
#
# 1. Check that the determined polynomial info for the first dither only

# %%
print(dms[0].meta.filename + ':')
print(dms[0].meta.background.polynomial_info)
# Out:
# det_image_seq2_MIRIFUSHORT_12SHORTexp1_mrsimatchstep.fits:
# [{'refpoint': (-1.6376430947558577e-05, -7.714131695841923e-06, 4.847613704135425), 'degree': (1, 1, 1), 'channel': '1', 'coefficients': [0.2529508693343559, -0.09265422251665069, -283.44874321044995, 69.86378974006863, -0.0007231915812298881, 0.00045596658900712544, 0.5854433768574536, -0.35524139772019203]}, {'refpoint': (-3.260911443125035e-05, -9.314696877009318e-05, 7.445174730317602), 'degree': (1, 1, 1), 'channel': '2', 'coefficients': [-0.06467528362949398, -0.021214341504164812, -34.783466095382906, -9.261128774084852, 0.0004880838101312369, 6.947401454626364e-05, 0.5557590647832195, 0.011771753499670835]}]

# %% [markdown]
# ## OUTLIER_DETECTION step ======================================
# Flag outlier bad pixels and missed cosmic rays in the DQ array of each input image. See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/outlier_detection/index.html

# %% [markdown]
# ### OUTLIER_DETECTION: load module and show options

# %%
# import the step
from jwst.outlier_detection import outlier_detection_step

# print the description and options
print(outlier_detection_step.OutlierDetectionStep.__doc__)
print(outlier_detection_step.OutlierDetectionStep.spec)
# Out:
# Flag outlier bad pixels and cosmic rays in DQ array of each input image.
#
#     Input images can listed in an input association file or already opened
#     with a ModelContainer.  DQ arrays are modified in place.
#
#     Parameters
#     -----------
#     input : asn file or ModelContainer
#         Single filename association table, or a datamodels.ModelContainer.
#
#
#
#         wht_type = option('exptime','error',None,default='exptime')
#         pixfrac = float(default=1.0)
#         kernel = string(default='square') # drizzle kernel
#         fillval = string(default='INDEF')
#         nlow = integer(default=0)
#         nhigh = integer(default=0)
#         maskpt = float(default=0.7)
#         grow = integer(default=1)
#         snr = string(default='4.0 3.0')
#         scale = string(default='0.5 0.4')
#         backg = float(default=0.0)
#         save_intermediate_results = boolean(default=False)
#         resample_data = boolean(default=True)
#         good_bits = integer(default=4)
#         scale_detection = boolean(default=False)
#         search_output_file = boolean(default=False)

# %% [markdown]
# ### OUTLIER_DETECTION: run step

# %%
# run step
dms = outlier_detection_step.OutlierDetectionStep.call(dms)
# Out:
# 2019-02-01 10:46:57,833 - stpipe.OutlierDetectionStep - INFO - OutlierDetectionStep instance created.
# 2019-02-01 10:46:58,367 - stpipe.OutlierDetectionStep - INFO - Step OutlierDetectionStep running with args (<ModelContainer>,).
# 2019-02-01 10:47:06,574 - stpipe.OutlierDetectionStep - INFO - Performing outlier detection on 4 inputs
# 2019-02-01 10:47:28,825 - stpipe.OutlierDetectionStep - INFO - Performing IFU outlier_detection for exptype MIR_MRS
# 2019-02-01 10:47:28,828 - stpipe.CubeBuildStep - INFO - CubeBuildStep instance created.
# 2019-02-01 10:47:28,829 - stpipe.CubeBuildStep - INFO - Starting IFU Cube Building Step
# 2019-02-01 10:47:28,829 - stpipe.CubeBuildStep - INFO - Input interpolation: pointcloud
# 2019-02-01 10:47:28,830 - stpipe.CubeBuildStep - INFO - Coordinate system to use: ra-dec
# 2019-02-01 10:47:28,830 - stpipe.CubeBuildStep - INFO - Weighting method for point cloud: msm
# 2019-02-01 10:47:28,831 - stpipe.CubeBuildStep - INFO - Power Weighting distance : 2.000000
# 2019-02-01 10:47:49,707 - stpipe.OutlierDetectionStep - INFO - The desired cubes covers the MIRI Channels: ['1']
# 2019-02-01 10:47:49,709 - stpipe.OutlierDetectionStep - INFO - The desired cubes covers the MIRI subchannels: ['SHORT']
# 2019-02-01 10:47:49,709 - stpipe.OutlierDetectionStep - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits
# 2019-02-01 10:47:52,521 - stpipe.OutlierDetectionStep - INFO -  Single = true, creating a set of single exposures mapped to output IFUCube coordinate system
# 2019-02-01 10:47:52,521 - stpipe.CubeBuildStep - INFO - Number of IFUCubes produced by a this run 1
# 2019-02-01 10:47:52,524 - stpipe.OutlierDetectionStep - INFO - Increasing spatial region of interest default value set for 4 dithers 0.150000
# 2019-02-01 10:47:52,525 - stpipe.OutlierDetectionStep - INFO - Region of interest spatial, wavelength  0.150000 0.001000
# 2019-02-01 10:47:52,525 - stpipe.OutlierDetectionStep - INFO - Number of bands in cube  1
# 2019-02-01 10:47:53,099 - stpipe.OutlierDetectionStep - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/gwcs/selector.py:444: RuntimeWarning: invalid value encountered in less_equal
#   temp = np.where(np.logical_or(temp <= val_range[0],
#
# 2019-02-01 10:47:53,101 - stpipe.OutlierDetectionStep - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/gwcs/selector.py:445: RuntimeWarning: invalid value encountered in greater_equal
#   temp >= val_range[1]),
#
# 2019-02-01 10:47:55,198 - stpipe.OutlierDetectionStep - INFO - Ra average -0.00001612.8
# 2019-02-01 10:47:55,201 - stpipe.OutlierDetectionStep - INFO - Cube Geometry:
# 2019-02-01 10:47:55,202 - stpipe.OutlierDetectionStep - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2019-02-01 10:47:55,202 - stpipe.OutlierDetectionStep - INFO - Axis 1    52  27.00  -0.00001638   0.13000000  -3.44499987   3.44499987
# 2019-02-01 10:47:55,203 - stpipe.OutlierDetectionStep - INFO - Axis 2    38  20.00  -0.00000771   0.13000000  -2.53499991   2.53499991
# 2019-02-01 10:47:55,204 - stpipe.OutlierDetectionStep - INFO - Axis 3   929   1.00   4.84761370   0.00100000   4.84761370   5.77661375
# 2019-02-01 10:47:55,204 - stpipe.OutlierDetectionStep - INFO - Cube covers channel, subchannel: 1 SHORT
# 2019-02-01 10:48:41,736 - stpipe.OutlierDetectionStep - INFO - Time to interpolate at spaxel values = 1.1.s
# 2019-02-01 10:48:41,823 - stpipe.OutlierDetectionStep - INFO - Blending metadata for
# 2019-02-01 10:48:44,294 - stpipe.OutlierDetectionStep - INFO - Time Create Single IFUcube  = 49.1.s
# 2019-02-01 10:49:30,209 - stpipe.OutlierDetectionStep - INFO - Time to interpolate at spaxel values = 1.1.s
# 2019-02-01 10:49:30,294 - stpipe.OutlierDetectionStep - INFO - Blending metadata for
# 2019-02-01 10:49:32,773 - stpipe.OutlierDetectionStep - INFO - Time Create Single IFUcube  = 48.4.s
# 2019-02-01 10:50:18,310 - stpipe.OutlierDetectionStep - INFO - Time to interpolate at spaxel values = 1.2.s
# 2019-02-01 10:50:18,396 - stpipe.OutlierDetectionStep - INFO - Blending metadata for
# 2019-02-01 10:50:20,872 - stpipe.OutlierDetectionStep - INFO - Time Create Single IFUcube  = 48.0.s
# 2019-02-01 10:51:07,126 - stpipe.OutlierDetectionStep - INFO - Time to interpolate at spaxel values = 1.2.s
# 2019-02-01 10:51:07,212 - stpipe.OutlierDetectionStep - INFO - Blending metadata for
# 2019-02-01 10:51:09,816 - stpipe.OutlierDetectionStep - INFO - Time Create Single IFUcube  = 48.8.s
# 2019-02-01 10:51:09,932 - stpipe.CubeBuildStep - INFO - Number of IFUCube models returned from building single IFUCubes 4
# 2019-02-01 10:51:13,415 - stpipe.OutlierDetectionStep - INFO - Information on Blotting
# 2019-02-01 10:51:13,416 - stpipe.OutlierDetectionStep - INFO - Working with instrument MIRI MIRIFUSHORT
# 2019-02-01 10:51:13,416 - stpipe.OutlierDetectionStep - INFO - shape of sky cube 52.000000 38.000000 929.000000
# 2019-02-01 10:51:13,417 - stpipe.OutlierDetectionStep - INFO - Instrument MIRI
# 2019-02-01 10:51:13,418 - stpipe.OutlierDetectionStep - INFO - Channel 1
# 2019-02-01 10:51:13,418 - stpipe.OutlierDetectionStep - INFO - Sub-channel SHORT
# 2019-02-01 10:51:13,419 - stpipe.OutlierDetectionStep - INFO - ROI size (spatial and wave) 0.150000 0.001000
# 2019-02-01 10:51:13,420 - stpipe.OutlierDetectionStep - INFO - Number of input models 4
# 2019-02-01 10:51:14,298 - stpipe.OutlierDetectionStep - INFO - Blotting back det_image_seq2_MIRIFUSHORT_12SHORTexp1_cal.fits
# 2019-02-01 10:54:05,328 - stpipe.OutlierDetectionStep - INFO - Blotting back det_image_seq1_MIRIFUSHORT_12SHORTexp1_cal.fits
# 2019-02-01 10:56:55,167 - stpipe.OutlierDetectionStep - INFO - Blotting back det_image_seq3_MIRIFUSHORT_12SHORTexp1_cal.fits
# 2019-02-01 10:59:46,565 - stpipe.OutlierDetectionStep - INFO - Blotting back det_image_seq4_MIRIFUSHORT_12SHORTexp1_cal.fits
# 2019-02-01 11:02:47,902 - stpipe.OutlierDetectionStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq2_MIRIFUSHORT_12SHORTexp1_a3001_outlierdetectionstep.fits
# 2019-02-01 11:02:49,837 - stpipe.OutlierDetectionStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq1_MIRIFUSHORT_12SHORTexp1_a3001_outlierdetectionstep.fits
# 2019-02-01 11:02:51,727 - stpipe.OutlierDetectionStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq3_MIRIFUSHORT_12SHORTexp1_a3001_outlierdetectionstep.fits
# 2019-02-01 11:02:53,531 - stpipe.OutlierDetectionStep - INFO - Saved model in MRS_demo_data_tutorial/det_image_seq4_MIRIFUSHORT_12SHORTexp1_a3001_outlierdetectionstep.fits
# 2019-02-01 11:02:53,532 - stpipe.OutlierDetectionStep - INFO - Step OutlierDetectionStep done

# %% [markdown]
# ## CUBE_BUILD step ======================================
# In the level 3 pipeline, this step builds a cube from all level 2B files in the association, i.e., combining the dithers. See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/cube_build/index.html

# %% [markdown]
# ### CUBE_BUILD: load module and show options

# %%
from jwst.cube_build import cube_build_step

# print the description and options
print(cube_build_step.CubeBuildStep.__doc__)
print(cube_build_step.CubeBuildStep.spec)
# Out:
#     CubeBuildStep: Creates a 3-D spectral cube from a given association, single model,
#     single input file, or model container.
#     Input parameters allow the spectral cube to be built from a provided
#     channel/subchannel (MIRI) or grating/filer  (NIRSPEC)
#
#
#          channel = option('1','2','3','4','ALL','all',default='ALL') # Options: 1,2,3,4,or All
#          band = option('SHORT','MEDIUM','LONG','ALL','short','medium','long','all',default='ALL') # Options: SHORT,MEDIUM,LONG, or ALL
#          grating   = option('PRISM','G140M','G140H','G235M','G235H',G395M','G395H','ALL','all',default='ALL')  # Options: PRISM,G140M,G140H,G235M,G235H,G395M,G395H, or ALL
#          filter   = option('CLEAR','F100LP','F070LP','F170LP','F290LP','ALL','all',default='ALL') # Options: CLEAR,F100LP,F070LP,F170LP,F290LP, or ALL
#          scale1 = float(default=0.0) # cube sample size to use for axis 1, arc seconds
#          scale2 = float(default=0.0) # cube sample size to use for axis 2, arc seconds
#          scalew = float(default=0.0) # cube sample size to use for axis 3, microns
#          weighting = option('msm','miripsf','area','MSM','MIRIPSF','AREA',default = 'msm') # Type of weighting function,
#          coord_system = option('ra-dec','alpha-beta','ALPHA-BETA',default='ra-dec') # Output Coordinate system. Options: ra-dec or alpha-beta
#          rois = float(default=0.0) # region of interest spatial size, arc seconds
#          roiw = float(default=0.0) # region of interest wavelength size, microns
#          weight_power = float(default=2.0) # Weighting option to use for Modified Shepard Method
#          offset_list = string(default='NA')  # A file for dithered data containing additional ra and dec offsets
#          wavemin = float(default=None)  # Minimum wavelength to be used in the IFUCube
#          wavemax = float(default=None)  # Maximum wavelength to be used in the IFUCube
#          xdebug = integer(default=None) # debug option, x spaxel value to report information on
#          ydebug = integer(default=None) # debug option, y spaxel value to report information on
#          zdebug = integer(default=None) # debug option, z spaxel value to report  information on
#          single = boolean(default=false) # Internal pipeline option used by mrs_imatch and outlier detection
#          output_type = option('band','channel','grating','multi',default='band') # Type IFUcube to create. Options=band,channel,grating,multi
#          search_output_file = boolean(default=false)
#          output_use_model = boolean(default=true) # Use filenames in the output models

# %% [markdown]
# ### CUBE_BUILD: run step

# %%
# run step
cube_dm = cube_build_step.CubeBuildStep.call(dms, save_results=True, output_dir=output_dir)
# Out:
# 2019-02-01 11:02:53,558 - stpipe.CubeBuildStep - INFO - CubeBuildStep instance created.
# 2019-02-01 11:02:54,550 - stpipe.CubeBuildStep - INFO - Step CubeBuildStep running with args (<ModelContainer>,).
# 2019-02-01 11:02:54,551 - stpipe.CubeBuildStep - INFO - Starting IFU Cube Building Step
# 2019-02-01 11:02:54,552 - stpipe.CubeBuildStep - INFO - Input interpolation: pointcloud
# 2019-02-01 11:02:54,553 - stpipe.CubeBuildStep - INFO - Coordinate system to use: ra-dec
# 2019-02-01 11:02:54,554 - stpipe.CubeBuildStep - INFO - Weighting method for point cloud: msm
# 2019-02-01 11:02:54,555 - stpipe.CubeBuildStep - INFO - Power Weighting distance : 2.000000
# 2019-02-01 11:02:54,926 - stpipe.CubeBuildStep - INFO - The desired cubes covers the MIRI Channels: ['1', '2']
# 2019-02-01 11:02:54,928 - stpipe.CubeBuildStep - INFO - The desired cubes covers the MIRI subchannels: ['SHORT', 'SHORT']
# 2019-02-01 11:02:54,930 - stpipe.CubeBuildStep - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0002.fits
# 2019-02-01 11:02:58,674 - stpipe.CubeBuildStep - INFO - Output Cubes are single channel, single sub-channel IFU Cubes
# 2019-02-01 11:02:58,675 - stpipe.CubeBuildStep - INFO - Number of IFUCubes produced by a this run 2
# 2019-02-01 11:02:58,681 - stpipe.CubeBuildStep - INFO - Region of interest spatial, wavelength  0.100000 0.001000
# 2019-02-01 11:02:58,682 - stpipe.CubeBuildStep - INFO - Number of bands in cube  1
# 2019-02-01 11:02:59,320 - stpipe.CubeBuildStep - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/gwcs/selector.py:444: RuntimeWarning: invalid value encountered in less_equal
#   temp = np.where(np.logical_or(temp <= val_range[0],
#
# 2019-02-01 11:02:59,321 - stpipe.CubeBuildStep - WARNING - /anaconda3/envs/mirisim/lib/python3.5/site-packages/gwcs/selector.py:445: RuntimeWarning: invalid value encountered in greater_equal
#   temp >= val_range[1]),
#
# 2019-02-01 11:03:02,004 - stpipe.CubeBuildStep - INFO - Ra average -0.00001612.8
# 2019-02-01 11:03:02,009 - stpipe.CubeBuildStep - INFO - Cube Geometry:
# 2019-02-01 11:03:02,011 - stpipe.CubeBuildStep - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2019-02-01 11:03:02,012 - stpipe.CubeBuildStep - INFO - Axis 1    52  27.00  -0.00001638   0.13000000  -3.44499987   3.44499987
# 2019-02-01 11:03:02,013 - stpipe.CubeBuildStep - INFO - Axis 2    38  20.00  -0.00000771   0.13000000  -2.53499991   2.53499991
# 2019-02-01 11:03:02,014 - stpipe.CubeBuildStep - INFO - Axis 3   929   1.00   4.84761370   0.00100000   4.84761370   5.77661375
# 2019-02-01 11:03:02,014 - stpipe.CubeBuildStep - INFO - Cube covers channel, subchannel: 1 SHORT
# 2019-02-01 11:03:02,015 - stpipe.CubeBuildStep - INFO - Output Name MRS_demo_data_tutorial/dither_ch1-short_s3d.fits
# 2019-02-01 11:05:34,828 - stpipe.CubeBuildStep - INFO - Time Map All slices on Detector to Cube = 148.4.s
# 2019-02-01 11:05:36,512 - stpipe.CubeBuildStep - INFO - Time to interpolate at spaxel values = 1.7.s
# 2019-02-01 11:05:36,513 - stpipe.CubeBuildStep - INFO - Time to find Cube Flux= 1.7.s
# 2019-02-01 11:05:36,621 - stpipe.CubeBuildStep - INFO - Blending metadata for MRS_demo_data_tutorial/dither_ch1-short_s3d.fits
# 2019-02-01 11:05:40,690 - stpipe.CubeBuildStep - INFO - Region of interest spatial, wavelength  0.150000 0.002000
# 2019-02-01 11:05:40,691 - stpipe.CubeBuildStep - INFO - Number of bands in cube  1
# 2019-02-01 11:05:43,222 - stpipe.CubeBuildStep - INFO - Ra average -0.00003312.8
# 2019-02-01 11:05:43,225 - stpipe.CubeBuildStep - INFO - Cube Geometry:
# 2019-02-01 11:05:43,225 - stpipe.CubeBuildStep - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2019-02-01 11:05:43,226 - stpipe.CubeBuildStep - INFO - Axis 1    46  24.00  -0.00003261   0.17000000  -3.99500004   3.99500004
# 2019-02-01 11:05:43,226 - stpipe.CubeBuildStep - INFO - Axis 2    36  19.00  -0.00009315   0.17000000  -3.14500003   3.14500003
# 2019-02-01 11:05:43,227 - stpipe.CubeBuildStep - INFO - Axis 3   716   1.00   7.44517473   0.00200000   7.44517473   8.87717480
# 2019-02-01 11:05:43,228 - stpipe.CubeBuildStep - INFO - Cube covers channel, subchannel: 2 SHORT
# 2019-02-01 11:05:43,229 - stpipe.CubeBuildStep - INFO - Output Name MRS_demo_data_tutorial/dither_ch2-short_s3d.fits
# 2019-02-01 11:07:51,773 - stpipe.CubeBuildStep - INFO - Time Map All slices on Detector to Cube = 126.6.s
# 2019-02-01 11:07:52,800 - stpipe.CubeBuildStep - INFO - Time to interpolate at spaxel values = 1.0.s
# 2019-02-01 11:07:52,801 - stpipe.CubeBuildStep - INFO - Time to find Cube Flux= 1.0.s
# 2019-02-01 11:07:52,868 - stpipe.CubeBuildStep - INFO - Blending metadata for MRS_demo_data_tutorial/dither_ch2-short_s3d.fits
# 2019-02-01 11:07:56,043 - stpipe.CubeBuildStep - INFO - Saved model in MRS_demo_data_tutorial/dither_ch1-short_s3d.fits
# 2019-02-01 11:07:56,813 - stpipe.CubeBuildStep - INFO - Saved model in MRS_demo_data_tutorial/dither_ch2-short_s3d.fits
# 2019-02-01 11:07:56,816 - stpipe.CubeBuildStep - INFO - Step CubeBuildStep done

# %% [markdown]
# ### CUBE_BUILD: plot the channels of the cube

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].imshow(np.sum(cube_dm[0].data[50:-50], axis=0), cmap='jet', interpolation='nearest', origin='lower', 
              norm=LogNorm(vmin=50,vmax=5e4))
axs[0].annotate('Collapsed cube: short channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, 
                fontweight='bold', color='k')
axs[0].set_facecolor('black')
axs[1].imshow(np.sum(cube_dm[1].data[50:-50], axis=0), cmap='jet', interpolation='nearest', origin='lower', 
              norm=LogNorm(vmin=50,vmax=5e4))
axs[1].annotate('Collapsed cube: long channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, 
                fontweight='bold', color='k')
axs[1].set_facecolor('black')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## EXTRACT_1D step ======================================
# In the level 3 pipeline, this step extracts a 1D spectrum from the combined cube. See:
#
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/extract_1d/index.html
#
# As above, since the source_type step above should have set SRCTYPE to 'EXTENDED', the extract_1d step will use an rectangular extraction region with default values. The aperture centre is at pixel x/2, y/2, the width and height are x/2 and y/2, respectively. In the future, more advanced extraction methods are planned. One can set also the aperture properties using a custom aperture reference file. Please contact pkavanagh@cp.dias.ie if you want to do this.

# %% [markdown]
# ### EXTRACT_1D: load module and show options

# %%
from jwst.extract_1d import extract_1d_step

# print the description and options
print(extract_1d_step.Extract1dStep.__doc__)
print(extract_1d_step.Extract1dStep.spec)
# Out:
#     Extract1dStep: Extract a 1-d spectrum from 2-d data
#
#
#     # Boxcar smoothing width for background regions.
#     smoothing_length = integer(default=None)
#     # Order of polynomial fit to one column (or row if the dispersion
#     # direction is vertical) of background regions.
#     bkg_order = integer(default=None, min=0)
#     # Log a progress message when processing multi-integration data.
#     log_increment = integer(default=50)

# %% [markdown]
# ### EXTRACT_1D: run step

# %%
# run step
spec_dm = extract_1d_step.Extract1dStep.call(cube_dm, save_results=True, output_use_model=True,
                                             output_dir=output_dir)
# Out:
# 2019-02-01 11:07:57,104 - stpipe.Extract1dStep - INFO - Extract1dStep instance created.
# 2019-02-01 11:07:57,571 - stpipe.Extract1dStep - INFO - Step Extract1dStep running with args (<ModelContainer>,).
# 2019-02-01 11:07:57,581 - stpipe.Extract1dStep - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2019-02-01 11:07:57,616 - stpipe.Extract1dStep - INFO - source_type = point
# 2019-02-01 11:08:00,194 - stpipe.Extract1dStep - INFO - Data have been flux calibrated; setting net to 0.
# 2019-02-01 11:08:00,260 - stpipe.Extract1dStep - WARNING - INTSTART not found; assuming a value of 1.
# 2019-02-01 11:08:00,261 - stpipe.Extract1dStep - WARNING - INTEND not found; assuming a value of 2.
# 2019-02-01 11:08:00,262 - stpipe.Extract1dStep - WARNING - There is no INT_TIMES table in the input file.
# 2019-02-01 11:08:00,267 - stpipe.Extract1dStep - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2019-02-01 11:08:00,303 - stpipe.Extract1dStep - INFO - source_type = point
# 2019-02-01 11:08:02,336 - stpipe.Extract1dStep - INFO - Data have been flux calibrated; setting net to 0.
# 2019-02-01 11:08:02,399 - stpipe.Extract1dStep - WARNING - INTSTART not found; assuming a value of 1.
# 2019-02-01 11:08:02,400 - stpipe.Extract1dStep - WARNING - INTEND not found; assuming a value of 2.
# 2019-02-01 11:08:02,401 - stpipe.Extract1dStep - WARNING - There is no INT_TIMES table in the input file.
# 2019-02-01 11:08:02,489 - stpipe.Extract1dStep - INFO - Saved model in MRS_demo_data_tutorial/dither_ch1-short_extract1dstep.fits
# 2019-02-01 11:08:02,577 - stpipe.Extract1dStep - INFO - Saved model in MRS_demo_data_tutorial/dither_ch2-short_extract1dstep.fits
# 2019-02-01 11:08:02,578 - stpipe.Extract1dStep - INFO - Step Extract1dStep done

# %% [markdown]
# ### EXTRACT_1D: plot spectrum
#
# Again, the extracted spectra are in units of mJy/arcsec^2. To convert these to mJy we multiply by the spaxel area. We also correct for the MIRISim beginning of life transmission factor. Note that an additional correction for the encircled energy in the aperture using the PSF CDP is also required but we forego this here.

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

# plot the spectrum in the channel 2 wavelength range
spaxel_area = cube_dm[0].meta.wcsinfo.cdelt1 * cube_dm[0].meta.wcsinfo.cdelt2 * 3600**2
axs[0].plot(spec_dm[0].spec[0].spec_table['WAVELENGTH'], 
            spec_dm[0].spec[0].spec_table['FLUX'] * spaxel_area, 
            c='orange', marker='.', markersize=0, linestyle='-', linewidth=2)
axs[0].set_ylabel(r'Flux (mJy)')
axs[0].set_xlabel(r'Wavelength ($\mu$m)')
axs[0].set_xlim(4.9,5.7)
axs[0].set_ylim(75,200)
axs[0].annotate('Channel 1', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[0].grid()
spaxel_area = cube_dm[1].meta.wcsinfo.cdelt1 * cube_dm[1].meta.wcsinfo.cdelt2 * 3600**2
axs[1].plot(spec_dm[1].spec[0].spec_table['WAVELENGTH'], 
            spec_dm[1].spec[0].spec_table['FLUX']  * spaxel_area, 
            c='g', marker='.', markersize=0, linestyle='-', linewidth=2)
axs[1].set_xlabel(r'Wavelength ($\mu$m)')
axs[1].set_xlim(7.5,8.7)
axs[1].annotate('Channel 2', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[1].grid()

plt.tight_layout()
plt.show()
